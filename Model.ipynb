# %%
from string import punctuation
from os import listdir
from collections import Counter
from nltk.corpus import stopwords
 
# load doc into memory
def load_doc(filename):
	# open the file as read only
	file = open(filename, 'r')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text
 
# load doc, clean and return line of tokens
def doc_to_line(filename, vocab):
	# load the doc
	doc = load_doc(filename)
	# clean doc
	tokens = clean_doc(doc)
	# filter by vocab
	tokens = [w for w in tokens if w in vocab]
	return ' '.join(tokens)
 
# load all docs in a directory
def process_docs(directory, vocab):
	lines = list()
	# walk through all files in the folder
	for filename in listdir(directory):
		# skip any reviews in the test set
		if filename.startswith('cv9'):
			continue
		# create the full path of the file to open
		path = directory + '/' + filename
		# load and clean the doc
		line = doc_to_line(path, vocab)
		# add to list
		lines.append(line)
	return lines
 
# load the vocabulary
vocab_filename = 'vocab.txt'
vocab = load_doc(vocab_filename)
vocab = vocab.split()
vocab = set(vocab)
# load all training reviews
positive_lines = process_docs('txt_sentoken/pos', vocab)
negative_lines = process_docs('txt_sentoken/neg', vocab)
# summarize what we have
print(len(positive_lines), len(negative_lines))
# Out:
# 900 900

# %%
vocab_filename = 'vocab.txt'
vocab = load_doc(vocab_filename)
vocab = vocab.split()
vocab = set(vocab)

# %%
def process_docs(directory, vocab):
	lines = list()
	# walk through all files in the folder
	for filename in listdir(directory):
		# skip any reviews in the test set
		if filename.startswith('cv9'):
			continue
		# create the full path of the file to open
		path = directory + '/' + filename
		# load and clean the doc
		line = doc_to_line(path, vocab)
		# add to list
		lines.append(line)
	return lines
 
    
    # load all training reviews
positive_lines = process_docs('txt_sentoken/pos', vocab)
negative_lines = process_docs('txt_sentoken/neg', vocab)
# summarize what we have
print(len(positive_lines), len(negative_lines))
# Out:
# 900 900

# %%
# create the tokenizer
tokenizer = Tokenizer()
# fit the tokenizer on the documents
docs = positive_lines + negative_lines
tokenizer.fit_on_texts(docs)

# %%
# encode training data set
Xtrain = tokenizer.texts_to_matrix(docs, mode='freq')
print(Xtrain.shape)
# Out:
# (1800, 25768)

# %%
def process_docs(directory, vocab, is_trian):
	lines = list()
	# walk through all files in the folder
	for filename in listdir(directory):
		# skip any reviews in the test set
		if is_trian and filename.startswith('cv9'):
			continue
		if not is_trian and not filename.startswith('cv9'):
			continue
		# create the full path of the file to open
		path = directory + '/' + filename
		# load and clean the doc
		line = doc_to_line(path, vocab)
		# add to list
		lines.append(line)
	return lines

# %%
# load all test reviews
positive_lines = process_docs('txt_sentoken/pos', vocab, False)
negative_lines = process_docs('txt_sentoken/neg', vocab, False)
docs = negative_lines + positive_lines
# encode training data set
Xtest = tokenizer.texts_to_matrix(docs, mode='freq')
print(Xtest.shape)
# Out:
# (200, 25768)

# %%
print(Xtrain.shape)
# Out:
# (1800, 25768)

# %%
from numpy import array
from string import punctuation
from os import listdir
from collections import Counter
from nltk.corpus import stopwords
from keras.preprocessing.text import Tokenizer
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
 
# load doc into memory
def load_doc(filename):
	# open the file as read only
	file = open(filename, 'r')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text
 
# turn a doc into clean tokens
def clean_doc(doc):
	# split into tokens by white space
	tokens = doc.split()
	# remove punctuation from each token
	table = str.maketrans('', '', punctuation)
	tokens = [w.translate(table) for w in tokens]
	# remove remaining tokens that are not alphabetic
	tokens = [word for word in tokens if word.isalpha()]
	# filter out stop words
	stop_words = set(stopwords.words('english'))
	tokens = [w for w in tokens if not w in stop_words]
	# filter out short tokens
	tokens = [word for word in tokens if len(word) > 1]
	return tokens
 
# load doc, clean and return line of tokens
def doc_to_line(filename, vocab):
	# load the doc
	doc = load_doc(filename)
	# clean doc
	tokens = clean_doc(doc)
	# filter by vocab
	tokens = [w for w in tokens if w in vocab]
	return ' '.join(tokens)
 
# load all docs in a directory
def process_docs(directory, vocab, is_trian):
	lines = list()
	# walk through all files in the folder
	for filename in listdir(directory):
		# skip any reviews in the test set
		if is_trian and filename.startswith('cv9'):
			continue
		if not is_trian and not filename.startswith('cv9'):
			continue
		# create the full path of the file to open
		path = directory + '/' + filename
		# load and clean the doc
		line = doc_to_line(path, vocab)
		# add to list
		lines.append(line)
	return lines
 
# load the vocabulary
vocab_filename = 'vocab.txt'
vocab = load_doc(vocab_filename)
vocab = vocab.split()
vocab = set(vocab)
# load all training reviews
positive_lines = process_docs('txt_sentoken/pos', vocab, True)
negative_lines = process_docs('txt_sentoken/neg', vocab, True)
# create the tokenizer
tokenizer = Tokenizer()

# fit the tokenizer on the documents
docs = negative_lines + positive_lines
#^This order over here and then in the ytrain line maps negative to 0 and positive to 1. 
#This will be important during prediction

tokenizer.fit_on_texts(docs)
# encode training data set
Xtrain = tokenizer.texts_to_matrix(docs, mode='freq')
ytrain = array([0 for _ in range(900)] + [1 for _ in range(900)])
 
# load all test reviews
positive_lines = process_docs('txt_sentoken/pos', vocab, False)
negative_lines = process_docs('txt_sentoken/neg', vocab, False)
docs = negative_lines + positive_lines
# encode training data set
Xtest = tokenizer.texts_to_matrix(docs, mode='freq')
ytest = array([0 for _ in range(100)] + [1 for _ in range(100)])
 
n_words = Xtest.shape[1]
# define network
model = Sequential()
model.add(Dense(50, input_shape=(n_words,), activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# compile network
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# fit network
model.fit(Xtrain, ytrain, epochs=50, verbose=2)
# evaluate
loss, acc = model.evaluate(Xtest, ytest, verbose=0)
print('Test Accuracy: %f' % (acc*100))
# Out:
# Epoch 1/50
#  - 1s - loss: 0.6918 - accuracy: 0.5294
# Epoch 2/50
#  - 1s - loss: 0.6827 - accuracy: 0.6739
# Epoch 3/50
#  - 1s - loss: 0.6640 - accuracy: 0.8622
# Epoch 4/50
#  - 1s - loss: 0.6331 - accuracy: 0.9156
# Epoch 5/50
#  - 1s - loss: 0.5934 - accuracy: 0.9261
# Epoch 6/50
#  - 1s - loss: 0.5472 - accuracy: 0.9417
# Epoch 7/50
#  - 1s - loss: 0.4999 - accuracy: 0.9489
# Epoch 8/50
#  - 1s - loss: 0.4520 - accuracy: 0.9550
# Epoch 9/50
#  - 1s - loss: 0.4078 - accuracy: 0.9539
# Epoch 10/50
#  - 1s - loss: 0.3648 - accuracy: 0.9622
# Epoch 11/50
#  - 1s - loss: 0.3276 - accuracy: 0.9728
# Epoch 12/50
#  - 1s - loss: 0.2931 - accuracy: 0.9783
# Epoch 13/50
#  - 1s - loss: 0.2627 - accuracy: 0.9800
# Epoch 14/50
#  - 1s - loss: 0.2355 - accuracy: 0.9844
# Epoch 15/50
#  - 1s - loss: 0.2118 - accuracy: 0.9894
# Epoch 16/50
#  - 1s - loss: 0.1905 - accuracy: 0.9906
# Epoch 17/50
#  - 1s - loss: 0.1714 - accuracy: 0.9928
# Epoch 18/50
#  - 1s - loss: 0.1547 - accuracy: 0.9939
# Epoch 19/50
#  - 1s - loss: 0.1405 - accuracy: 0.9939
# Epoch 20/50
#  - 1s - loss: 0.1267 - accuracy: 0.9956
# Epoch 21/50
#  - 1s - loss: 0.1151 - accuracy: 0.9967
# Epoch 22/50
#  - 1s - loss: 0.1047 - accuracy: 0.9967
# Epoch 23/50
#  - 1s - loss: 0.0950 - accuracy: 0.9989
# Epoch 24/50
#  - 1s - loss: 0.0870 - accuracy: 0.9983
# Epoch 25/50
#  - 1s - loss: 0.0793 - accuracy: 0.9994
# Epoch 26/50
#  - 1s - loss: 0.0725 - accuracy: 0.9994
# Epoch 27/50
#  - 1s - loss: 0.0665 - accuracy: 1.0000
# Epoch 28/50
#  - 1s - loss: 0.0610 - accuracy: 1.0000
# Epoch 29/50
#  - 1s - loss: 0.0562 - accuracy: 1.0000
# Epoch 30/50
#  - 1s - loss: 0.0516 - accuracy: 1.0000
# Epoch 31/50
#  - 1s - loss: 0.0477 - accuracy: 1.0000
# Epoch 32/50
#  - 1s - loss: 0.0440 - accuracy: 1.0000
# Epoch 33/50
#  - 1s - loss: 0.0407 - accuracy: 1.0000
# Epoch 34/50
#  - 1s - loss: 0.0377 - accuracy: 1.0000
# Epoch 35/50
#  - 1s - loss: 0.0351 - accuracy: 1.0000
# Epoch 36/50
#  - 1s - loss: 0.0326 - accuracy: 1.0000
# Epoch 37/50
#  - 1s - loss: 0.0303 - accuracy: 1.0000
# Epoch 38/50
#  - 1s - loss: 0.0283 - accuracy: 1.0000
# Epoch 39/50
#  - 1s - loss: 0.0263 - accuracy: 1.0000
# Epoch 40/50
#  - 1s - loss: 0.0245 - accuracy: 1.0000
# Epoch 41/50
#  - 1s - loss: 0.0230 - accuracy: 1.0000
# Epoch 42/50
#  - 1s - loss: 0.0216 - accuracy: 1.0000
# Epoch 43/50
#  - 1s - loss: 0.0202 - accuracy: 1.0000
# Epoch 44/50
#  - 1s - loss: 0.0190 - accuracy: 1.0000
# Epoch 45/50
#  - 1s - loss: 0.0178 - accuracy: 1.0000
# Epoch 46/50
#  - 1s - loss: 0.0167 - accuracy: 1.0000
# Epoch 47/50
#  - 1s - loss: 0.0158 - accuracy: 1.0000
# Epoch 48/50
#  - 2s - loss: 0.0148 - accuracy: 1.0000
# Epoch 49/50
#  - 1s - loss: 0.0140 - accuracy: 1.0000
# Epoch 50/50
#  - 1s - loss: 0.0132 - accuracy: 1.0000
# Test Accuracy: 90.499997

# %%
7
from numpy import array
from string import punctuation
from os import listdir
from collections import Counter
from nltk.corpus import stopwords
from keras.preprocessing.text import Tokenizer
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from pandas import DataFrame
from matplotlib import pyplot
 
# load doc into memory
def load_doc(filename):
	# open the file as read only
	file = open(filename, 'r')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text
 
# turn a doc into clean tokens
def clean_doc(doc):
	# split into tokens by white space
	tokens = doc.split()
	# remove punctuation from each token
	table = str.maketrans('', '', punctuation)
	tokens = [w.translate(table) for w in tokens]
	# remove remaining tokens that are not alphabetic
	tokens = [word for word in tokens if word.isalpha()]
	# filter out stop words
	stop_words = set(stopwords.words('english'))
	tokens = [w for w in tokens if not w in stop_words]
	# filter out short tokens
	tokens = [word for word in tokens if len(word) > 1]
	return tokens
 
# load doc, clean and return line of tokens
def doc_to_line(filename, vocab):
	# load the doc
	doc = load_doc(filename)
	# clean doc
	tokens = clean_doc(doc)
	# filter by vocab
	tokens = [w for w in tokens if w in vocab]
	return ' '.join(tokens)
 
# load all docs in a directory
def process_docs(directory, vocab, is_trian):
	lines = list()
	# walk through all files in the folder
	for filename in listdir(directory):
		# skip any reviews in the test set
		if is_trian and filename.startswith('cv9'):
			continue
		if not is_trian and not filename.startswith('cv9'):
			continue
		# create the full path of the file to open
		path = directory + '/' + filename
		# load and clean the doc
		line = doc_to_line(path, vocab)
		# add to list
		lines.append(line)
	return lines
 
# evaluate a neural network model
def evaluate_mode(Xtrain, ytrain, Xtest, ytest):
	scores = list()
	n_repeats = 30
	n_words = Xtest.shape[1]
	for i in range(n_repeats):
		# define network
		model = Sequential()
		model.add(Dense(50, input_shape=(n_words,), activation='relu'))
		model.add(Dense(1, activation='sigmoid'))
		# compile network
		model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
		# fit network
		model.fit(Xtrain, ytrain, epochs=50, verbose=2)
		# evaluate
		loss, acc = model.evaluate(Xtest, ytest, verbose=0)
		scores.append(acc)
		print('%d accuracy: %s' % ((i+1), acc))
	return scores
 
# prepare bag of words encoding of docs
def prepare_data(train_docs, test_docs, mode):
	# create the tokenizer
	tokenizer = Tokenizer()
	# fit the tokenizer on the documents
	tokenizer.fit_on_texts(train_docs)
	# encode training data set
	Xtrain = tokenizer.texts_to_matrix(train_docs, mode=mode)
	# encode training data set
	Xtest = tokenizer.texts_to_matrix(test_docs, mode=mode)
	return Xtrain, Xtest
 
# load the vocabulary
vocab_filename = 'vocab.txt'
vocab = load_doc(vocab_filename)
vocab = vocab.split()
vocab = set(vocab)
# load all training reviews
positive_lines = process_docs('txt_sentoken/pos', vocab, True)
negative_lines = process_docs('txt_sentoken/neg', vocab, True)
train_docs = negative_lines + positive_lines
# load all test reviews
positive_lines = process_docs('txt_sentoken/pos', vocab, False)
negative_lines = process_docs('txt_sentoken/neg', vocab, False)
test_docs = negative_lines + positive_lines
# prepare labels
ytrain = array([0 for _ in range(900)] + [1 for _ in range(900)])
ytest = array([0 for _ in range(100)] + [1 for _ in range(100)])
 
modes = ['binary', 'count', 'tfidf', 'freq']
results = DataFrame()
for mode in modes:
	# prepare data for mode
	Xtrain, Xtest = prepare_data(train_docs, test_docs, mode)
	# evaluate model on data for mode
	results[mode] = evaluate_mode(Xtrain, ytrain, Xtest, ytest)
# summarize results
print(results.describe())
# plot results
results.boxplot()
pyplot.show()
# Out:
# Epoch 1/50
#  - 2s - loss: 0.4765 - accuracy: 0.7800
# Epoch 2/50
#  - 1s - loss: 0.0621 - accuracy: 0.9944
# Epoch 3/50
#  - 1s - loss: 0.0165 - accuracy: 1.0000
# Epoch 4/50
#  - 1s - loss: 0.0075 - accuracy: 1.0000
# Epoch 5/50
#  - 1s - loss: 0.0043 - accuracy: 1.0000
# Epoch 6/50
#  - 1s - loss: 0.0026 - accuracy: 1.0000
# Epoch 7/50
#  - 1s - loss: 0.0018 - accuracy: 1.0000
# Epoch 8/50
#  - 1s - loss: 0.0013 - accuracy: 1.0000
# Epoch 9/50
#  - 2s - loss: 9.9544e-04 - accuracy: 1.0000
# Epoch 10/50
#  - 1s - loss: 7.8771e-04 - accuracy: 1.0000
# Epoch 11/50
#  - 2s - loss: 6.4228e-04 - accuracy: 1.0000
# Epoch 12/50
#  - 1s - loss: 5.3790e-04 - accuracy: 1.0000
# Epoch 13/50
#  - 1s - loss: 4.5514e-04 - accuracy: 1.0000
# Epoch 14/50
#  - 1s - loss: 3.9111e-04 - accuracy: 1.0000
# Epoch 15/50
#  - 1s - loss: 3.4126e-04 - accuracy: 1.0000
# Epoch 16/50
#  - 1s - loss: 3.0005e-04 - accuracy: 1.0000
# Epoch 17/50
#  - 1s - loss: 2.6640e-04 - accuracy: 1.0000
# Epoch 18/50
#  - 1s - loss: 2.3784e-04 - accuracy: 1.0000
# Epoch 19/50
#  - 1s - loss: 2.1384e-04 - accuracy: 1.0000
# Epoch 20/50
#  - 1s - loss: 1.9326e-04 - accuracy: 1.0000
# Epoch 21/50
#  - 1s - loss: 1.7501e-04 - accuracy: 1.0000
# Epoch 22/50
#  - 1s - loss: 1.5942e-04 - accuracy: 1.0000
# Epoch 23/50
#  - 1s - loss: 1.4582e-04 - accuracy: 1.0000
# Epoch 24/50
#  - 1s - loss: 1.3382e-04 - accuracy: 1.0000
# Epoch 25/50
#  - 1s - loss: 1.2336e-04 - accuracy: 1.0000
# Epoch 26/50
#  - 1s - loss: 1.1393e-04 - accuracy: 1.0000
# Epoch 27/50
#  - 1s - loss: 1.0523e-04 - accuracy: 1.0000
# Epoch 28/50
#  - 1s - loss: 9.7829e-05 - accuracy: 1.0000
# Epoch 29/50
#  - 1s - loss: 9.0874e-05 - accuracy: 1.0000
# Epoch 30/50
#  - 1s - loss: 8.4633e-05 - accuracy: 1.0000
# Epoch 31/50
#  - 1s - loss: 7.9010e-05 - accuracy: 1.0000
# Epoch 32/50
#  - 1s - loss: 7.3894e-05 - accuracy: 1.0000
# Epoch 33/50
#  - 1s - loss: 6.9133e-05 - accuracy: 1.0000
# Epoch 34/50
#  - 1s - loss: 6.4900e-05 - accuracy: 1.0000
# Epoch 35/50
#  - 1s - loss: 6.0918e-05 - accuracy: 1.0000
# Epoch 36/50
#  - 1s - loss: 5.7300e-05 - accuracy: 1.0000
# Epoch 37/50
#  - 1s - loss: 5.3996e-05 - accuracy: 1.0000
# Epoch 38/50
#  - 1s - loss: 5.0856e-05 - accuracy: 1.0000
# Epoch 39/50
#  - 1s - loss: 4.7938e-05 - accuracy: 1.0000
# Epoch 40/50
#  - 1s - loss: 4.5275e-05 - accuracy: 1.0000
# Epoch 41/50
#  - 1s - loss: 4.2827e-05 - accuracy: 1.0000
# Epoch 42/50
#  - 1s - loss: 4.0534e-05 - accuracy: 1.0000
# Epoch 43/50
#  - 1s - loss: 3.8397e-05 - accuracy: 1.0000
# Epoch 44/50
#  - 1s - loss: 3.6473e-05 - accuracy: 1.0000
# Epoch 45/50
#  - 1s - loss: 3.4547e-05 - accuracy: 1.0000
# Epoch 46/50
#  - 1s - loss: 3.2843e-05 - accuracy: 1.0000
# Epoch 47/50
#  - 1s - loss: 3.1204e-05 - accuracy: 1.0000
# Epoch 48/50
#  - 1s - loss: 2.9668e-05 - accuracy: 1.0000
# Epoch 49/50
#  - 1s - loss: 2.8228e-05 - accuracy: 1.0000
# Epoch 50/50
#  - 1s - loss: 2.6914e-05 - accuracy: 1.0000
# 1 accuracy: 0.9100000262260437
# Epoch 1/50
#  - 1s - loss: 0.4494 - accuracy: 0.8044
# Epoch 2/50
#  - 1s - loss: 0.0423 - accuracy: 0.9972
# Epoch 3/50
#  - 1s - loss: 0.0129 - accuracy: 1.0000
# Epoch 4/50
#  - 1s - loss: 0.0070 - accuracy: 1.0000
# Epoch 5/50
#  - 1s - loss: 0.0043 - accuracy: 1.0000
# Epoch 6/50
#  - 1s - loss: 0.0028 - accuracy: 1.0000
# Epoch 7/50
#  - 1s - loss: 0.0019 - accuracy: 1.0000
# Epoch 8/50
#  - 1s - loss: 0.0013 - accuracy: 1.0000
# Epoch 9/50
#  - 1s - loss: 9.3184e-04 - accuracy: 1.0000
# Epoch 10/50
#  - 1s - loss: 6.9907e-04 - accuracy: 1.0000
# Epoch 11/50
#  - 1s - loss: 5.4496e-04 - accuracy: 1.0000
# Epoch 12/50
#  - 1s - loss: 4.3538e-04 - accuracy: 1.0000
# Epoch 13/50
#  - 1s - loss: 3.5853e-04 - accuracy: 1.0000
# Epoch 14/50
#  - 1s - loss: 2.9928e-04 - accuracy: 1.0000
# Epoch 15/50
#  - 1s - loss: 2.5400e-04 - accuracy: 1.0000
# Epoch 16/50
#  - 1s - loss: 2.1767e-04 - accuracy: 1.0000
# Epoch 17/50
#  - 1s - loss: 1.8902e-04 - accuracy: 1.0000
# Epoch 18/50
#  - 1s - loss: 1.6615e-04 - accuracy: 1.0000
# Epoch 19/50
#  - 1s - loss: 1.4613e-04 - accuracy: 1.0000
# Epoch 20/50
#  - 1s - loss: 1.3008e-04 - accuracy: 1.0000
# Epoch 21/50
#  - 1s - loss: 1.1630e-04 - accuracy: 1.0000
# Epoch 22/50
#  - 1s - loss: 1.0461e-04 - accuracy: 1.0000
# Epoch 23/50
#  - 1s - loss: 9.4583e-05 - accuracy: 1.0000
# Epoch 24/50
#  - 1s - loss: 8.5831e-05 - accuracy: 1.0000
# Epoch 25/50
#  - 1s - loss: 7.8343e-05 - accuracy: 1.0000
# Epoch 26/50
#  - 1s - loss: 7.1677e-05 - accuracy: 1.0000
# Epoch 27/50
#  - 1s - loss: 6.5884e-05 - accuracy: 1.0000
# Epoch 28/50
#  - 1s - loss: 6.0729e-05 - accuracy: 1.0000
# Epoch 29/50
#  - 1s - loss: 5.6145e-05 - accuracy: 1.0000
# Epoch 30/50
#  - 1s - loss: 5.1952e-05 - accuracy: 1.0000
# Epoch 31/50
#  - 1s - loss: 4.8356e-05 - accuracy: 1.0000
# Epoch 32/50
#  - 1s - loss: 4.4837e-05 - accuracy: 1.0000
# Epoch 33/50
#  - 1s - loss: 4.1775e-05 - accuracy: 1.0000
# Epoch 34/50
#  - 1s - loss: 3.9046e-05 - accuracy: 1.0000
# Epoch 35/50
#  - 1s - loss: 3.6458e-05 - accuracy: 1.0000
# Epoch 36/50
#  - 1s - loss: 3.4148e-05 - accuracy: 1.0000
# Epoch 37/50
#  - 1s - loss: 3.2058e-05 - accuracy: 1.0000
# Epoch 38/50
#  - 1s - loss: 3.0119e-05 - accuracy: 1.0000
# Epoch 39/50
#  - 1s - loss: 2.8317e-05 - accuracy: 1.0000
# Epoch 40/50
#  - 1s - loss: 2.6702e-05 - accuracy: 1.0000
# Epoch 41/50
#  - 1s - loss: 2.5182e-05 - accuracy: 1.0000
# Epoch 42/50
#  - 1s - loss: 2.3782e-05 - accuracy: 1.0000
# Epoch 43/50
#  - 1s - loss: 2.2489e-05 - accuracy: 1.0000
# Epoch 44/50
#  - 1s - loss: 2.1248e-05 - accuracy: 1.0000
# Epoch 45/50
#  - 1s - loss: 2.0121e-05 - accuracy: 1.0000
# Epoch 46/50
#  - 1s - loss: 1.9087e-05 - accuracy: 1.0000
# Epoch 47/50
#  - 1s - loss: 1.8119e-05 - accuracy: 1.0000
# Epoch 48/50
#  - 1s - loss: 1.7202e-05 - accuracy: 1.0000
# Epoch 49/50
#  - 1s - loss: 1.6339e-05 - accuracy: 1.0000
# Epoch 50/50
#  - 1s - loss: 1.5555e-05 - accuracy: 1.0000
# 2 accuracy: 0.9300000071525574
# Epoch 1/50
#  - 1s - loss: 0.4665 - accuracy: 0.7783
# Epoch 2/50
#  - 1s - loss: 0.0550 - accuracy: 0.9956
# Epoch 3/50
#  - 1s - loss: 0.0151 - accuracy: 1.0000
# Epoch 4/50
#  - 1s - loss: 0.0077 - accuracy: 1.0000
# Epoch 5/50
#  - 1s - loss: 0.0047 - accuracy: 1.0000
# Epoch 6/50
#  - 2s - loss: 0.0031 - accuracy: 1.0000
# Epoch 7/50
#  - 1s - loss: 0.0022 - accuracy: 1.0000
# Epoch 8/50
#  - 1s - loss: 0.0015 - accuracy: 1.0000
# Epoch 9/50
#  - 1s - loss: 0.0010 - accuracy: 1.0000
# Epoch 10/50
#  - 1s - loss: 7.4300e-04 - accuracy: 1.0000
# Epoch 11/50
#  - 1s - loss: 5.5972e-04 - accuracy: 1.0000
# Epoch 12/50
#  - 1s - loss: 4.3386e-04 - accuracy: 1.0000
# Epoch 13/50
#  - 1s - loss: 3.4663e-04 - accuracy: 1.0000
# Epoch 14/50
#  - 1s - loss: 2.8368e-04 - accuracy: 1.0000
# Epoch 15/50
#  - 1s - loss: 2.3654e-04 - accuracy: 1.0000
# Epoch 16/50
#  - 1s - loss: 2.0015e-04 - accuracy: 1.0000
# Epoch 17/50
#  - 1s - loss: 1.7164e-04 - accuracy: 1.0000
# Epoch 18/50
#  - 1s - loss: 1.4908e-04 - accuracy: 1.0000
# Epoch 19/50
#  - 1s - loss: 1.3040e-04 - accuracy: 1.0000
# Epoch 20/50
#  - 1s - loss: 1.1513e-04 - accuracy: 1.0000
# Epoch 21/50
#  - 1s - loss: 1.0244e-04 - accuracy: 1.0000
# Epoch 22/50
#  - 1s - loss: 9.1652e-05 - accuracy: 1.0000
# Epoch 23/50
#  - 2s - loss: 8.2463e-05 - accuracy: 1.0000
# Epoch 24/50
#  - 1s - loss: 7.4827e-05 - accuracy: 1.0000
# Epoch 25/50
#  - 1s - loss: 6.7804e-05 - accuracy: 1.0000
# Epoch 26/50
#  - 1s - loss: 6.1821e-05 - accuracy: 1.0000
# Epoch 27/50
#  - 1s - loss: 5.6639e-05 - accuracy: 1.0000
# Epoch 28/50
#  - 1s - loss: 5.2042e-05 - accuracy: 1.0000
# Epoch 29/50
#  - 1s - loss: 4.7937e-05 - accuracy: 1.0000
# Epoch 30/50
#  - 1s - loss: 4.4322e-05 - accuracy: 1.0000
# Epoch 31/50
#  - 1s - loss: 4.1071e-05 - accuracy: 1.0000
# Epoch 32/50
#  - 1s - loss: 3.8079e-05 - accuracy: 1.0000
# Epoch 33/50
#  - 1s - loss: 3.5715e-05 - accuracy: 1.0000
# Epoch 34/50
#  - 1s - loss: 3.2993e-05 - accuracy: 1.0000
# Epoch 35/50
#  - 1s - loss: 3.0866e-05 - accuracy: 1.0000
# Epoch 36/50
#  - 1s - loss: 2.8853e-05 - accuracy: 1.0000
# Epoch 37/50
#  - 1s - loss: 2.7103e-05 - accuracy: 1.0000
# Epoch 38/50
#  - 1s - loss: 2.5402e-05 - accuracy: 1.0000
# Epoch 39/50
#  - 1s - loss: 2.3885e-05 - accuracy: 1.0000
# Epoch 40/50
#  - 1s - loss: 2.2488e-05 - accuracy: 1.0000
# Epoch 41/50
#  - 1s - loss: 2.1204e-05 - accuracy: 1.0000
# Epoch 42/50
#  - 1s - loss: 2.0024e-05 - accuracy: 1.0000
# Epoch 43/50
#  - 1s - loss: 1.8920e-05 - accuracy: 1.0000
# Epoch 44/50
#  - 1s - loss: 1.7891e-05 - accuracy: 1.0000
# Epoch 45/50
#  - 1s - loss: 1.6936e-05 - accuracy: 1.0000
# Epoch 46/50
#  - 1s - loss: 1.6054e-05 - accuracy: 1.0000
# Epoch 47/50
#  - 1s - loss: 1.5208e-05 - accuracy: 1.0000
# Epoch 48/50
#  - 1s - loss: 1.4446e-05 - accuracy: 1.0000
# Epoch 49/50
#  - 1s - loss: 1.3703e-05 - accuracy: 1.0000
# Epoch 50/50
#  - 1s - loss: 1.3030e-05 - accuracy: 1.0000
# 3 accuracy: 0.925000011920929
# Epoch 1/50
#  - 2s - loss: 0.4775 - accuracy: 0.7861
# Epoch 2/50
#  - 1s - loss: 0.0691 - accuracy: 0.9933
# Epoch 3/50
#  - 1s - loss: 0.0205 - accuracy: 1.0000
# Epoch 4/50
#  - 1s - loss: 0.0083 - accuracy: 1.0000
# Epoch 5/50
#  - 1s - loss: 0.0041 - accuracy: 1.0000
# Epoch 6/50
#  - 1s - loss: 0.0023 - accuracy: 1.0000
# Epoch 7/50
#  - 1s - loss: 0.0014 - accuracy: 1.0000
# Epoch 8/50
#  - 1s - loss: 9.3557e-04 - accuracy: 1.0000
# Epoch 9/50
#  - 1s - loss: 6.6967e-04 - accuracy: 1.0000
# Epoch 10/50
#  - 1s - loss: 5.0439e-04 - accuracy: 1.0000
# Epoch 11/50
#  - 1s - loss: 3.9504e-04 - accuracy: 1.0000
# Epoch 12/50
#  - 1s - loss: 3.1677e-04 - accuracy: 1.0000
# Epoch 13/50
#  - 1s - loss: 2.5973e-04 - accuracy: 1.0000
# Epoch 14/50
#  - 1s - loss: 2.1696e-04 - accuracy: 1.0000
# Epoch 15/50
#  - 1s - loss: 1.8409e-04 - accuracy: 1.0000
# Epoch 16/50
#  - 1s - loss: 1.5783e-04 - accuracy: 1.0000
# Epoch 17/50
#  - 1s - loss: 1.3673e-04 - accuracy: 1.0000
# Epoch 18/50
#  - 1s - loss: 1.1971e-04 - accuracy: 1.0000
# Epoch 19/50
#  - 1s - loss: 1.0522e-04 - accuracy: 1.0000
# Epoch 20/50
#  - 1s - loss: 9.3337e-05 - accuracy: 1.0000
# Epoch 21/50
#  - 1s - loss: 8.3063e-05 - accuracy: 1.0000
# Epoch 22/50
#  - 1s - loss: 7.4640e-05 - accuracy: 1.0000
# Epoch 23/50
#  - 1s - loss: 6.7204e-05 - accuracy: 1.0000
# Epoch 24/50
#  - 1s - loss: 6.0817e-05 - accuracy: 1.0000
# Epoch 25/50
#  - 1s - loss: 5.5323e-05 - accuracy: 1.0000
# Epoch 26/50
#  - 1s - loss: 5.0462e-05 - accuracy: 1.0000
# Epoch 27/50
#  - 1s - loss: 4.6303e-05 - accuracy: 1.0000
# Epoch 28/50
#  - 1s - loss: 4.2468e-05 - accuracy: 1.0000
# Epoch 29/50
#  - 1s - loss: 3.9073e-05 - accuracy: 1.0000
# Epoch 30/50
#  - 1s - loss: 3.6115e-05 - accuracy: 1.0000
# Epoch 31/50
#  - 1s - loss: 3.3407e-05 - accuracy: 1.0000
# Epoch 32/50
#  - 1s - loss: 3.1010e-05 - accuracy: 1.0000
# Epoch 33/50
#  - 1s - loss: 2.8815e-05 - accuracy: 1.0000
# Epoch 34/50
#  - 1s - loss: 2.6841e-05 - accuracy: 1.0000
# Epoch 35/50
#  - 1s - loss: 2.5044e-05 - accuracy: 1.0000
# Epoch 36/50
#  - 1s - loss: 2.3427e-05 - accuracy: 1.0000
# Epoch 37/50
#  - 1s - loss: 2.1906e-05 - accuracy: 1.0000
# Epoch 38/50
#  - 1s - loss: 2.0548e-05 - accuracy: 1.0000
# Epoch 39/50
#  - 1s - loss: 1.9282e-05 - accuracy: 1.0000
# Epoch 40/50
#  - 1s - loss: 1.8114e-05 - accuracy: 1.0000
# Epoch 41/50
#  - 1s - loss: 1.7045e-05 - accuracy: 1.0000
# Epoch 42/50
#  - 1s - loss: 1.6070e-05 - accuracy: 1.0000
# Epoch 43/50
#  - 1s - loss: 1.5148e-05 - accuracy: 1.0000
# Epoch 44/50
#  - 1s - loss: 1.4286e-05 - accuracy: 1.0000
# Epoch 45/50
#  - 1s - loss: 1.3500e-05 - accuracy: 1.0000
# Epoch 46/50
#  - 1s - loss: 1.2755e-05 - accuracy: 1.0000
# Epoch 47/50
#  - 1s - loss: 1.2056e-05 - accuracy: 1.0000
# Epoch 48/50
#  - 1s - loss: 1.1389e-05 - accuracy: 1.0000
# Epoch 49/50
#  - 1s - loss: 1.0751e-05 - accuracy: 1.0000
# Epoch 50/50
#  - 1s - loss: 1.0114e-05 - accuracy: 1.0000
# 4 accuracy: 0.9200000166893005
# Epoch 1/50
#  - 1s - loss: 0.5233 - accuracy: 0.7617
# Epoch 2/50
#  - 1s - loss: 0.0978 - accuracy: 0.9806
# Epoch 3/50
#  - 1s - loss: 0.0180 - accuracy: 1.0000
# Epoch 4/50
#  - 1s - loss: 0.0077 - accuracy: 1.0000
# Epoch 5/50
#  - 1s - loss: 0.0042 - accuracy: 1.0000
# Epoch 6/50
#  - 1s - loss: 0.0027 - accuracy: 1.0000
# Epoch 7/50
#  - 1s - loss: 0.0018 - accuracy: 1.0000
# Epoch 8/50
#  - 1s - loss: 0.0012 - accuracy: 1.0000
# Epoch 9/50
#  - 1s - loss: 7.9170e-04 - accuracy: 1.0000
# Epoch 10/50
#  - 1s - loss: 5.2843e-04 - accuracy: 1.0000
# Epoch 11/50
#  - 1s - loss: 3.5809e-04 - accuracy: 1.0000
# Epoch 12/50
#  - 1s - loss: 2.5678e-04 - accuracy: 1.0000
# Epoch 13/50
#  - 1s - loss: 1.9535e-04 - accuracy: 1.0000
# Epoch 14/50
#  - 1s - loss: 1.5440e-04 - accuracy: 1.0000
# Epoch 15/50
#  - 1s - loss: 1.2522e-04 - accuracy: 1.0000
# Epoch 16/50
#  - 1s - loss: 1.0426e-04 - accuracy: 1.0000
# Epoch 17/50
#  - 1s - loss: 8.8301e-05 - accuracy: 1.0000
# Epoch 18/50
#  - 1s - loss: 7.5511e-05 - accuracy: 1.0000
# Epoch 19/50
#  - 1s - loss: 6.5474e-05 - accuracy: 1.0000
# Epoch 20/50
#  - 1s - loss: 5.7423e-05 - accuracy: 1.0000
# Epoch 21/50
#  - 1s - loss: 5.0693e-05 - accuracy: 1.0000
# Epoch 22/50
#  - 1s - loss: 4.4972e-05 - accuracy: 1.0000
# Epoch 23/50
#  - 1s - loss: 4.0200e-05 - accuracy: 1.0000
# Epoch 24/50
#  - 1s - loss: 3.6188e-05 - accuracy: 1.0000
# Epoch 25/50
#  - 1s - loss: 3.2700e-05 - accuracy: 1.0000
# Epoch 26/50
#  - 1s - loss: 3.0005e-05 - accuracy: 1.0000
# Epoch 27/50
#  - 1s - loss: 2.7064e-05 - accuracy: 1.0000
# Epoch 28/50
#  - 1s - loss: 2.4741e-05 - accuracy: 1.0000
# Epoch 29/50
#  - 1s - loss: 2.2700e-05 - accuracy: 1.0000
# Epoch 30/50
#  - 1s - loss: 2.0866e-05 - accuracy: 1.0000
# Epoch 31/50
#  - 1s - loss: 1.9290e-05 - accuracy: 1.0000
# Epoch 32/50
#  - 1s - loss: 1.7834e-05 - accuracy: 1.0000
# Epoch 33/50
#  - 1s - loss: 1.6530e-05 - accuracy: 1.0000
# Epoch 34/50
#  - 1s - loss: 1.5355e-05 - accuracy: 1.0000
# Epoch 35/50
#  - 1s - loss: 1.4300e-05 - accuracy: 1.0000
# Epoch 36/50
#  - 1s - loss: 1.3399e-05 - accuracy: 1.0000
# Epoch 37/50
#  - 1s - loss: 1.2454e-05 - accuracy: 1.0000
# Epoch 38/50
#  - 1s - loss: 1.1667e-05 - accuracy: 1.0000
# Epoch 39/50
#  - 1s - loss: 1.0937e-05 - accuracy: 1.0000
# Epoch 40/50
#  - 1s - loss: 1.0262e-05 - accuracy: 1.0000
# Epoch 41/50
#  - 1s - loss: 9.6486e-06 - accuracy: 1.0000
# Epoch 42/50
#  - 2s - loss: 9.0638e-06 - accuracy: 1.0000
# Epoch 43/50
#  - 1s - loss: 8.5571e-06 - accuracy: 1.0000
# Epoch 44/50
#  - 1s - loss: 8.0546e-06 - accuracy: 1.0000
# Epoch 45/50
#  - 1s - loss: 7.6083e-06 - accuracy: 1.0000
# Epoch 46/50
#  - 1s - loss: 7.2018e-06 - accuracy: 1.0000
# Epoch 47/50
#  - 1s - loss: 6.8087e-06 - accuracy: 1.0000
# Epoch 48/50
#  - 1s - loss: 6.4433e-06 - accuracy: 1.0000
# Epoch 49/50
#  - 1s - loss: 6.1082e-06 - accuracy: 1.0000
# Epoch 50/50
#  - 1s - loss: 5.7896e-06 - accuracy: 1.0000
# 5 accuracy: 0.9100000262260437
# Epoch 1/50
#  - 1s - loss: 0.5475 - accuracy: 0.7156
# Epoch 2/50
#  - 1s - loss: 0.1062 - accuracy: 0.9867
# Epoch 3/50
#  - 1s - loss: 0.0241 - accuracy: 1.0000
# Epoch 4/50
#  - 1s - loss: 0.0088 - accuracy: 1.0000
# Epoch 5/50
#  - 1s - loss: 0.0047 - accuracy: 1.0000
# Epoch 6/50
#  - 1s - loss: 0.0029 - accuracy: 1.0000
# Epoch 7/50
#  - 1s - loss: 0.0019 - accuracy: 1.0000
# Epoch 8/50
#  - 1s - loss: 0.0013 - accuracy: 1.0000
# Epoch 9/50
#  - 1s - loss: 9.8336e-04 - accuracy: 1.0000
# Epoch 10/50
#  - 1s - loss: 7.5803e-04 - accuracy: 1.0000
# Epoch 11/50
#  - 1s - loss: 6.0059e-04 - accuracy: 1.0000
# Epoch 12/50
#  - 1s - loss: 4.8816e-04 - accuracy: 1.0000
# Epoch 13/50
#  - 1s - loss: 4.0501e-04 - accuracy: 1.0000
# Epoch 14/50
#  - 1s - loss: 3.4054e-04 - accuracy: 1.0000
# Epoch 15/50
#  - 1s - loss: 2.8981e-04 - accuracy: 1.0000
# Epoch 16/50
#  - 1s - loss: 2.4990e-04 - accuracy: 1.0000
# Epoch 17/50
#  - 1s - loss: 2.1738e-04 - accuracy: 1.0000
# Epoch 18/50
#  - 1s - loss: 1.9060e-04 - accuracy: 1.0000
# Epoch 19/50
#  - 1s - loss: 1.6835e-04 - accuracy: 1.0000
# Epoch 20/50
#  - 1s - loss: 1.4908e-04 - accuracy: 1.0000
# Epoch 21/50
#  - 1s - loss: 1.3223e-04 - accuracy: 1.0000
# Epoch 22/50
#  - 1s - loss: 1.1801e-04 - accuracy: 1.0000
# Epoch 23/50
#  - 1s - loss: 1.0527e-04 - accuracy: 1.0000
# Epoch 24/50
#  - 1s - loss: 9.4440e-05 - accuracy: 1.0000
# Epoch 25/50
#  - 1s - loss: 8.4916e-05 - accuracy: 1.0000
# Epoch 26/50
#  - 1s - loss: 7.6707e-05 - accuracy: 1.0000
# Epoch 27/50
#  - 1s - loss: 6.9531e-05 - accuracy: 1.0000
# Epoch 28/50
#  - 1s - loss: 6.3275e-05 - accuracy: 1.0000
# Epoch 29/50
#  - 1s - loss: 5.7641e-05 - accuracy: 1.0000
# Epoch 30/50
#  - 1s - loss: 5.2741e-05 - accuracy: 1.0000
# Epoch 31/50
#  - 1s - loss: 4.8266e-05 - accuracy: 1.0000
# Epoch 32/50
#  - 1s - loss: 4.4275e-05 - accuracy: 1.0000
# Epoch 33/50
#  - 1s - loss: 4.0710e-05 - accuracy: 1.0000
# Epoch 34/50
#  - 1s - loss: 3.7405e-05 - accuracy: 1.0000
# Epoch 35/50
#  - 1s - loss: 3.4538e-05 - accuracy: 1.0000
# Epoch 36/50
#  - 1s - loss: 3.1916e-05 - accuracy: 1.0000
# Epoch 37/50
#  - 1s - loss: 2.9523e-05 - accuracy: 1.0000
# Epoch 38/50
#  - 1s - loss: 2.7401e-05 - accuracy: 1.0000
# Epoch 39/50
#  - 1s - loss: 2.5447e-05 - accuracy: 1.0000
# Epoch 40/50
#  - 1s - loss: 2.3697e-05 - accuracy: 1.0000
# Epoch 41/50
#  - 1s - loss: 2.2058e-05 - accuracy: 1.0000
# Epoch 42/50
#  - 1s - loss: 2.0609e-05 - accuracy: 1.0000
# Epoch 43/50
#  - 1s - loss: 1.9232e-05 - accuracy: 1.0000
# Epoch 44/50
#  - 1s - loss: 1.8000e-05 - accuracy: 1.0000
# Epoch 45/50
#  - 1s - loss: 1.6821e-05 - accuracy: 1.0000
# Epoch 46/50
#  - 1s - loss: 1.5772e-05 - accuracy: 1.0000
# Epoch 47/50
#  - 1s - loss: 1.4798e-05 - accuracy: 1.0000
# Epoch 48/50
#  - 1s - loss: 1.3920e-05 - accuracy: 1.0000
# Epoch 49/50
#  - 1s - loss: 1.3094e-05 - accuracy: 1.0000
# Epoch 50/50
#  - 1s - loss: 1.2321e-05 - accuracy: 1.0000
# 6 accuracy: 0.9150000214576721
# Epoch 1/50
#  - 1s - loss: 0.5138 - accuracy: 0.7578
# Epoch 2/50
#  - 1s - loss: 0.0943 - accuracy: 0.9861
# Epoch 3/50
#  - 1s - loss: 0.0241 - accuracy: 1.0000
# Epoch 4/50
#  - 1s - loss: 0.0094 - accuracy: 1.0000
# Epoch 5/50
#  - 1s - loss: 0.0049 - accuracy: 1.0000
# Epoch 6/50
#  - 1s - loss: 0.0028 - accuracy: 1.0000
# Epoch 7/50
#  - 1s - loss: 0.0017 - accuracy: 1.0000
# Epoch 8/50
#  - 1s - loss: 0.0011 - accuracy: 1.0000
# Epoch 9/50
#  - 1s - loss: 7.7316e-04 - accuracy: 1.0000
# Epoch 10/50
#  - 1s - loss: 5.6976e-04 - accuracy: 1.0000
# Epoch 11/50
#  - 1s - loss: 4.4050e-04 - accuracy: 1.0000
# Epoch 12/50
#  - 1s - loss: 3.5268e-04 - accuracy: 1.0000
# Epoch 13/50
#  - 1s - loss: 2.9007e-04 - accuracy: 1.0000
# Epoch 14/50
#  - 1s - loss: 2.4377e-04 - accuracy: 1.0000
# Epoch 15/50
#  - 1s - loss: 2.0820e-04 - accuracy: 1.0000
# Epoch 16/50
#  - 1s - loss: 1.8080e-04 - accuracy: 1.0000
# Epoch 17/50
#  - 1s - loss: 1.5818e-04 - accuracy: 1.0000
# Epoch 18/50
#  - 1s - loss: 1.3967e-04 - accuracy: 1.0000
# Epoch 19/50
#  - 1s - loss: 1.2457e-04 - accuracy: 1.0000
# Epoch 20/50
#  - 1s - loss: 1.1154e-04 - accuracy: 1.0000
# Epoch 21/50
#  - 1s - loss: 1.0071e-04 - accuracy: 1.0000
# Epoch 22/50
#  - 1s - loss: 9.1283e-05 - accuracy: 1.0000
# Epoch 23/50
#  - 1s - loss: 8.3137e-05 - accuracy: 1.0000
# Epoch 24/50
#  - 1s - loss: 7.5936e-05 - accuracy: 1.0000
# Epoch 25/50
#  - 1s - loss: 6.9533e-05 - accuracy: 1.0000
# Epoch 26/50
#  - 1s - loss: 6.3880e-05 - accuracy: 1.0000
# Epoch 27/50
#  - 1s - loss: 5.9219e-05 - accuracy: 1.0000
# Epoch 28/50
#  - 1s - loss: 5.4613e-05 - accuracy: 1.0000
# Epoch 29/50
#  - 1s - loss: 5.0676e-05 - accuracy: 1.0000
# Epoch 30/50
#  - 1s - loss: 4.7096e-05 - accuracy: 1.0000
# Epoch 31/50
#  - 1s - loss: 4.3886e-05 - accuracy: 1.0000
# Epoch 32/50
#  - 1s - loss: 4.0976e-05 - accuracy: 1.0000
# Epoch 33/50
#  - 1s - loss: 3.7437e-05 - accuracy: 1.0000
# Epoch 34/50
#  - 1s - loss: 3.4994e-05 - accuracy: 1.0000
# Epoch 35/50
#  - 1s - loss: 3.2866e-05 - accuracy: 1.0000
# Epoch 36/50
#  - 1s - loss: 3.0943e-05 - accuracy: 1.0000
# Epoch 37/50
#  - 1s - loss: 2.9161e-05 - accuracy: 1.0000
# Epoch 38/50
#  - 1s - loss: 2.7499e-05 - accuracy: 1.0000
# Epoch 39/50
#  - 1s - loss: 2.6055e-05 - accuracy: 1.0000
# Epoch 40/50
#  - 1s - loss: 2.4573e-05 - accuracy: 1.0000
# Epoch 41/50
#  - 1s - loss: 2.3253e-05 - accuracy: 1.0000
# Epoch 42/50
#  - 1s - loss: 2.2022e-05 - accuracy: 1.0000
# Epoch 43/50
#  - 1s - loss: 2.0888e-05 - accuracy: 1.0000
# Epoch 44/50
#  - 1s - loss: 1.9822e-05 - accuracy: 1.0000
# Epoch 45/50
#  - 1s - loss: 1.8832e-05 - accuracy: 1.0000
# Epoch 46/50
#  - 1s - loss: 1.7895e-05 - accuracy: 1.0000
# Epoch 47/50
#  - 1s - loss: 1.7007e-05 - accuracy: 1.0000
# Epoch 48/50
#  - 1s - loss: 1.6182e-05 - accuracy: 1.0000
# Epoch 49/50
#  - 1s - loss: 1.5395e-05 - accuracy: 1.0000
# Epoch 50/50
#  - 1s - loss: 1.4634e-05 - accuracy: 1.0000
# 7 accuracy: 0.9300000071525574
# Epoch 1/50
#  - 1s - loss: 0.4862 - accuracy: 0.7711
# Epoch 2/50
#  - 1s - loss: 0.0696 - accuracy: 0.9900
# Epoch 3/50
#  - 1s - loss: 0.0151 - accuracy: 1.0000
# Epoch 4/50
#  - 1s - loss: 0.0060 - accuracy: 1.0000
# Epoch 5/50
#  - 1s - loss: 0.0030 - accuracy: 1.0000
# Epoch 6/50
#  - 1s - loss: 0.0018 - accuracy: 1.0000
# Epoch 7/50
#  - 1s - loss: 0.0012 - accuracy: 1.0000
# Epoch 8/50
#  - 1s - loss: 8.5935e-04 - accuracy: 1.0000
# Epoch 9/50
#  - 1s - loss: 6.4907e-04 - accuracy: 1.0000
# Epoch 10/50
#  - 1s - loss: 5.0730e-04 - accuracy: 1.0000
# Epoch 11/50
#  - 1s - loss: 4.0834e-04 - accuracy: 1.0000
# Epoch 12/50
#  - 1s - loss: 3.1863e-04 - accuracy: 1.0000
# Epoch 13/50
#  - 1s - loss: 2.6652e-04 - accuracy: 1.0000
# Epoch 14/50
#  - 1s - loss: 2.2587e-04 - accuracy: 1.0000
# Epoch 15/50
#  - 1s - loss: 1.9452e-04 - accuracy: 1.0000
# Epoch 16/50
#  - 1s - loss: 1.6895e-04 - accuracy: 1.0000
# Epoch 17/50
#  - 1s - loss: 1.4814e-04 - accuracy: 1.0000
# Epoch 18/50
#  - 1s - loss: 1.3086e-04 - accuracy: 1.0000
# Epoch 19/50
#  - 1s - loss: 1.1658e-04 - accuracy: 1.0000
# Epoch 20/50
#  - 1s - loss: 1.0427e-04 - accuracy: 1.0000
# Epoch 21/50
#  - 1s - loss: 9.3854e-05 - accuracy: 1.0000
# Epoch 22/50
#  - 1s - loss: 8.4846e-05 - accuracy: 1.0000
# Epoch 23/50
#  - 1s - loss: 7.6926e-05 - accuracy: 1.0000
# Epoch 24/50
#  - 1s - loss: 7.0090e-05 - accuracy: 1.0000
# Epoch 25/50
#  - 1s - loss: 6.4175e-05 - accuracy: 1.0000
# Epoch 26/50
#  - 1s - loss: 5.8775e-05 - accuracy: 1.0000
# Epoch 27/50
#  - 1s - loss: 5.4035e-05 - accuracy: 1.0000
# Epoch 28/50
#  - 1s - loss: 4.9924e-05 - accuracy: 1.0000
# Epoch 29/50
#  - 1s - loss: 4.5959e-05 - accuracy: 1.0000
# Epoch 30/50
#  - 1s - loss: 4.2595e-05 - accuracy: 1.0000
# Epoch 31/50
#  - 1s - loss: 3.9485e-05 - accuracy: 1.0000
# Epoch 32/50
#  - 1s - loss: 3.6667e-05 - accuracy: 1.0000
# Epoch 33/50
#  - 1s - loss: 3.4116e-05 - accuracy: 1.0000
# Epoch 34/50
#  - 1s - loss: 3.1809e-05 - accuracy: 1.0000
# Epoch 35/50
#  - 1s - loss: 2.9675e-05 - accuracy: 1.0000
# Epoch 36/50
#  - 1s - loss: 2.7738e-05 - accuracy: 1.0000
# Epoch 37/50
#  - 1s - loss: 2.5913e-05 - accuracy: 1.0000
# Epoch 38/50
#  - 1s - loss: 2.4268e-05 - accuracy: 1.0000
# Epoch 39/50
#  - 1s - loss: 2.2749e-05 - accuracy: 1.0000
# Epoch 40/50
#  - 1s - loss: 2.1382e-05 - accuracy: 1.0000
# Epoch 41/50
#  - 1s - loss: 2.0004e-05 - accuracy: 1.0000
# Epoch 42/50
#  - 1s - loss: 1.8867e-05 - accuracy: 1.0000
# Epoch 43/50
#  - 1s - loss: 1.7635e-05 - accuracy: 1.0000
# Epoch 44/50
#  - 1s - loss: 1.6602e-05 - accuracy: 1.0000
# Epoch 45/50
#  - 1s - loss: 1.5640e-05 - accuracy: 1.0000
# Epoch 46/50
#  - 1s - loss: 1.4743e-05 - accuracy: 1.0000
# Epoch 47/50
#  - 1s - loss: 1.3914e-05 - accuracy: 1.0000
# Epoch 48/50
#  - 1s - loss: 1.3147e-05 - accuracy: 1.0000
# Epoch 49/50
#  - 1s - loss: 1.2419e-05 - accuracy: 1.0000
# Epoch 50/50
#  - 1s - loss: 1.1751e-05 - accuracy: 1.0000
# 8 accuracy: 0.9350000023841858
# Epoch 1/50
#  - 1s - loss: 0.4886 - accuracy: 0.7622
# Epoch 2/50
#  - 1s - loss: 0.0654 - accuracy: 0.9939
# Epoch 3/50
#  - 1s - loss: 0.0176 - accuracy: 0.9994
# Epoch 4/50
#  - 1s - loss: 0.0084 - accuracy: 1.0000
# Epoch 5/50
#  - 1s - loss: 0.0051 - accuracy: 1.0000
# Epoch 6/50
#  - 1s - loss: 0.0031 - accuracy: 1.0000
# Epoch 7/50
#  - 1s - loss: 0.0021 - accuracy: 1.0000
# Epoch 8/50
#  - 1s - loss: 0.0015 - accuracy: 1.0000
# Epoch 9/50
#  - 1s - loss: 0.0011 - accuracy: 1.0000
# Epoch 10/50
#  - 1s - loss: 8.2878e-04 - accuracy: 1.0000
# Epoch 11/50
#  - 1s - loss: 6.5436e-04 - accuracy: 1.0000
# Epoch 12/50
#  - 1s - loss: 5.2901e-04 - accuracy: 1.0000
# Epoch 13/50
#  - 1s - loss: 4.3639e-04 - accuracy: 1.0000
# Epoch 14/50
#  - 1s - loss: 3.6607e-04 - accuracy: 1.0000
# Epoch 15/50
#  - 1s - loss: 3.1246e-04 - accuracy: 1.0000
# Epoch 16/50
#  - 1s - loss: 2.6866e-04 - accuracy: 1.0000
# Epoch 17/50
#  - 1s - loss: 2.3398e-04 - accuracy: 1.0000
# Epoch 18/50
#  - 1s - loss: 2.0545e-04 - accuracy: 1.0000
# Epoch 19/50
#  - 1s - loss: 1.8183e-04 - accuracy: 1.0000
# Epoch 20/50
#  - 1s - loss: 1.6185e-04 - accuracy: 1.0000
# Epoch 21/50
#  - 1s - loss: 1.4511e-04 - accuracy: 1.0000
# Epoch 22/50
#  - 1s - loss: 1.3061e-04 - accuracy: 1.0000
# Epoch 23/50
#  - 1s - loss: 1.1836e-04 - accuracy: 1.0000
# Epoch 24/50
#  - 1s - loss: 1.0725e-04 - accuracy: 1.0000
# Epoch 25/50
#  - 1s - loss: 9.7717e-05 - accuracy: 1.0000
# Epoch 26/50
#  - 1s - loss: 8.9372e-05 - accuracy: 1.0000
# Epoch 27/50
#  - 1s - loss: 8.2064e-05 - accuracy: 1.0000
# Epoch 28/50
#  - 1s - loss: 7.5067e-05 - accuracy: 1.0000
# Epoch 29/50
#  - 1s - loss: 6.8109e-05 - accuracy: 1.0000
# Epoch 30/50
#  - 1s - loss: 6.1287e-05 - accuracy: 1.0000
# Epoch 31/50
#  - 1s - loss: 5.5029e-05 - accuracy: 1.0000
# Epoch 32/50
#  - 1s - loss: 4.9569e-05 - accuracy: 1.0000
# Epoch 33/50
#  - 1s - loss: 4.4107e-05 - accuracy: 1.0000
# Epoch 34/50
#  - 1s - loss: 3.9385e-05 - accuracy: 1.0000
# Epoch 35/50
#  - 1s - loss: 3.5127e-05 - accuracy: 1.0000
# Epoch 36/50
#  - 1s - loss: 3.1445e-05 - accuracy: 1.0000
# Epoch 37/50
#  - 1s - loss: 2.8195e-05 - accuracy: 1.0000
# Epoch 38/50
#  - 1s - loss: 2.5322e-05 - accuracy: 1.0000
# Epoch 39/50
#  - 1s - loss: 2.2813e-05 - accuracy: 1.0000
# Epoch 40/50
#  - 1s - loss: 2.0667e-05 - accuracy: 1.0000
# Epoch 41/50
#  - 1s - loss: 1.8761e-05 - accuracy: 1.0000
# Epoch 42/50
#  - 1s - loss: 1.7056e-05 - accuracy: 1.0000
# Epoch 43/50
#  - 1s - loss: 1.5590e-05 - accuracy: 1.0000
# Epoch 44/50
#  - 1s - loss: 1.4291e-05 - accuracy: 1.0000
# Epoch 45/50
#  - 1s - loss: 1.3132e-05 - accuracy: 1.0000
# Epoch 46/50
#  - 1s - loss: 1.2141e-05 - accuracy: 1.0000
# Epoch 47/50
#  - 1s - loss: 1.1161e-05 - accuracy: 1.0000
# Epoch 48/50
#  - 1s - loss: 1.0362e-05 - accuracy: 1.0000
# Epoch 49/50
#  - 1s - loss: 9.5999e-06 - accuracy: 1.0000
# Epoch 50/50
#  - 1s - loss: 8.9178e-06 - accuracy: 1.0000
# 9 accuracy: 0.9200000166893005
# Epoch 1/50
#  - 1s - loss: 0.4803 - accuracy: 0.7744
# Epoch 2/50
#  - 1s - loss: 0.0553 - accuracy: 0.9961
# Epoch 3/50
#  - 1s - loss: 0.0162 - accuracy: 1.0000
# Epoch 4/50
#  - 1s - loss: 0.0073 - accuracy: 1.0000
# Epoch 5/50
#  - 1s - loss: 0.0042 - accuracy: 1.0000
# Epoch 6/50
#  - 1s - loss: 0.0026 - accuracy: 1.0000
# Epoch 7/50
#  - 1s - loss: 0.0018 - accuracy: 1.0000
# Epoch 8/50
#  - 1s - loss: 0.0013 - accuracy: 1.0000
# Epoch 9/50
#  - 1s - loss: 0.0010 - accuracy: 1.0000
# Epoch 10/50
#  - 1s - loss: 8.2339e-04 - accuracy: 1.0000
# Epoch 11/50
#  - 1s - loss: 6.5345e-04 - accuracy: 1.0000
# Epoch 12/50
#  - 1s - loss: 5.4436e-04 - accuracy: 1.0000
# Epoch 13/50
#  - 1s - loss: 4.6255e-04 - accuracy: 1.0000
# Epoch 14/50
#  - 1s - loss: 3.9994e-04 - accuracy: 1.0000
# Epoch 15/50
#  - 1s - loss: 3.4924e-04 - accuracy: 1.0000
# Epoch 16/50
#  - 1s - loss: 3.0673e-04 - accuracy: 1.0000
# Epoch 17/50
#  - 1s - loss: 2.7248e-04 - accuracy: 1.0000
# Epoch 18/50
#  - 1s - loss: 2.4360e-04 - accuracy: 1.0000
# Epoch 19/50
#  - 1s - loss: 2.1894e-04 - accuracy: 1.0000
# Epoch 20/50
#  - 1s - loss: 1.9815e-04 - accuracy: 1.0000
# Epoch 21/50
#  - 1s - loss: 1.7970e-04 - accuracy: 1.0000
# Epoch 22/50
#  - 1s - loss: 1.6372e-04 - accuracy: 1.0000
# Epoch 23/50
#  - 1s - loss: 1.4985e-04 - accuracy: 1.0000
# Epoch 24/50
#  - 1s - loss: 1.3765e-04 - accuracy: 1.0000
# Epoch 25/50
#  - 1s - loss: 1.2698e-04 - accuracy: 1.0000
# Epoch 26/50
#  - 1s - loss: 1.1735e-04 - accuracy: 1.0000
# Epoch 27/50
#  - 1s - loss: 1.0869e-04 - accuracy: 1.0000
# Epoch 28/50
#  - 1s - loss: 1.0087e-04 - accuracy: 1.0000
# Epoch 29/50
#  - 1s - loss: 9.3808e-05 - accuracy: 1.0000
# Epoch 30/50
#  - 1s - loss: 8.7549e-05 - accuracy: 1.0000
# Epoch 31/50
#  - 1s - loss: 8.1788e-05 - accuracy: 1.0000
# Epoch 32/50
#  - 1s - loss: 7.6437e-05 - accuracy: 1.0000
# Epoch 33/50
#  - 1s - loss: 7.1628e-05 - accuracy: 1.0000
# Epoch 34/50
#  - 1s - loss: 6.7154e-05 - accuracy: 1.0000
# Epoch 35/50
#  - 1s - loss: 6.3049e-05 - accuracy: 1.0000
# Epoch 36/50
#  - 1s - loss: 5.9192e-05 - accuracy: 1.0000
# Epoch 37/50
#  - 1s - loss: 5.5693e-05 - accuracy: 1.0000
# Epoch 38/50
#  - 1s - loss: 5.2386e-05 - accuracy: 1.0000
# Epoch 39/50
#  - 1s - loss: 4.9343e-05 - accuracy: 1.0000
# Epoch 40/50
#  - 1s - loss: 4.6510e-05 - accuracy: 1.0000
# Epoch 41/50
#  - 1s - loss: 4.3876e-05 - accuracy: 1.0000
# Epoch 42/50
#  - 1s - loss: 4.1431e-05 - accuracy: 1.0000
# Epoch 43/50
#  - 1s - loss: 3.9186e-05 - accuracy: 1.0000
# Epoch 44/50
#  - 1s - loss: 3.7093e-05 - accuracy: 1.0000
# Epoch 45/50
#  - 1s - loss: 3.5143e-05 - accuracy: 1.0000
# Epoch 46/50
#  - 1s - loss: 3.3353e-05 - accuracy: 1.0000
# Epoch 47/50
#  - 1s - loss: 3.1652e-05 - accuracy: 1.0000
# Epoch 48/50
#  - 1s - loss: 3.0099e-05 - accuracy: 1.0000
# Epoch 49/50
#  - 1s - loss: 2.8599e-05 - accuracy: 1.0000
# Epoch 50/50
#  - 1s - loss: 2.7230e-05 - accuracy: 1.0000
# 10 accuracy: 0.9200000166893005
# Epoch 1/50
#  - 1s - loss: 0.4703 - accuracy: 0.7911
# Epoch 2/50
#  - 1s - loss: 0.0590 - accuracy: 0.9944
# Epoch 3/50
#  - 1s - loss: 0.0161 - accuracy: 1.0000
# Epoch 4/50
#  - 1s - loss: 0.0071 - accuracy: 1.0000
# Epoch 5/50
#  - 1s - loss: 0.0040 - accuracy: 1.0000
# Epoch 6/50
#  - 1s - loss: 0.0025 - accuracy: 1.0000
# Epoch 7/50
#  - 1s - loss: 0.0018 - accuracy: 1.0000
# Epoch 8/50
#  - 1s - loss: 0.0013 - accuracy: 1.0000
# Epoch 9/50
#  - 1s - loss: 9.6745e-04 - accuracy: 1.0000
# Epoch 10/50
#  - 1s - loss: 7.5631e-04 - accuracy: 1.0000
# Epoch 11/50
#  - 1s - loss: 6.0862e-04 - accuracy: 1.0000
# Epoch 12/50
#  - 1s - loss: 4.9862e-04 - accuracy: 1.0000
# Epoch 13/50
#  - 1s - loss: 4.1551e-04 - accuracy: 1.0000
# Epoch 14/50
#  - 1s - loss: 3.5225e-04 - accuracy: 1.0000
# Epoch 15/50
#  - 1s - loss: 3.0175e-04 - accuracy: 1.0000
# Epoch 16/50
#  - 1s - loss: 2.6095e-04 - accuracy: 1.0000
# Epoch 17/50
#  - 1s - loss: 2.2740e-04 - accuracy: 1.0000
# Epoch 18/50
#  - 1s - loss: 1.9998e-04 - accuracy: 1.0000
# Epoch 19/50
#  - 1s - loss: 1.7709e-04 - accuracy: 1.0000
# Epoch 20/50
#  - 1s - loss: 1.5776e-04 - accuracy: 1.0000
# Epoch 21/50
#  - 1s - loss: 1.4137e-04 - accuracy: 1.0000
# Epoch 22/50
#  - 1s - loss: 1.2715e-04 - accuracy: 1.0000
# Epoch 23/50
#  - 1s - loss: 1.1500e-04 - accuracy: 1.0000
# Epoch 24/50
#  - 1s - loss: 1.0438e-04 - accuracy: 1.0000
# Epoch 25/50
#  - 1s - loss: 9.5301e-05 - accuracy: 1.0000
# Epoch 26/50
#  - 1s - loss: 8.6874e-05 - accuracy: 1.0000
# Epoch 27/50
#  - 1s - loss: 7.9678e-05 - accuracy: 1.0000
# Epoch 28/50
#  - 1s - loss: 7.3250e-05 - accuracy: 1.0000
# Epoch 29/50
#  - 1s - loss: 6.7610e-05 - accuracy: 1.0000
# Epoch 30/50
#  - 1s - loss: 6.2506e-05 - accuracy: 1.0000
# Epoch 31/50
#  - 1s - loss: 5.7937e-05 - accuracy: 1.0000
# Epoch 32/50
#  - 1s - loss: 5.3736e-05 - accuracy: 1.0000
# Epoch 33/50
#  - 1s - loss: 4.9996e-05 - accuracy: 1.0000
# Epoch 34/50
#  - 1s - loss: 4.6557e-05 - accuracy: 1.0000
# Epoch 35/50
#  - 1s - loss: 4.3456e-05 - accuracy: 1.0000
# Epoch 36/50
#  - 1s - loss: 4.0641e-05 - accuracy: 1.0000
# Epoch 37/50
#  - 1s - loss: 3.8018e-05 - accuracy: 1.0000
# Epoch 38/50
#  - 1s - loss: 3.5668e-05 - accuracy: 1.0000
# Epoch 39/50
#  - 1s - loss: 3.3471e-05 - accuracy: 1.0000
# Epoch 40/50
#  - 1s - loss: 3.1478e-05 - accuracy: 1.0000
# Epoch 41/50
#  - 1s - loss: 2.9630e-05 - accuracy: 1.0000
# Epoch 42/50
#  - 1s - loss: 2.7898e-05 - accuracy: 1.0000
# Epoch 43/50
#  - 1s - loss: 2.6290e-05 - accuracy: 1.0000
# Epoch 44/50
#  - 1s - loss: 2.4825e-05 - accuracy: 1.0000
# Epoch 45/50
#  - 1s - loss: 2.3465e-05 - accuracy: 1.0000
# Epoch 46/50
#  - 1s - loss: 2.2234e-05 - accuracy: 1.0000
# Epoch 47/50
#  - 1s - loss: 2.1012e-05 - accuracy: 1.0000
# Epoch 48/50
#  - 1s - loss: 1.9914e-05 - accuracy: 1.0000
# Epoch 49/50
#  - 1s - loss: 1.8883e-05 - accuracy: 1.0000
# Epoch 50/50
#  - 1s - loss: 1.7935e-05 - accuracy: 1.0000
# 11 accuracy: 0.9200000166893005
# Epoch 1/50
#  - 1s - loss: 0.4782 - accuracy: 0.7817
# Epoch 2/50
#  - 1s - loss: 0.0633 - accuracy: 0.9950
# Epoch 3/50
#  - 1s - loss: 0.0186 - accuracy: 1.0000
# Epoch 4/50
#  - 1s - loss: 0.0084 - accuracy: 1.0000
# Epoch 5/50
#  - 1s - loss: 0.0048 - accuracy: 1.0000
# Epoch 6/50
#  - 1s - loss: 0.0029 - accuracy: 1.0000
# Epoch 7/50
#  - 1s - loss: 0.0017 - accuracy: 1.0000
# Epoch 8/50
#  - 1s - loss: 0.0011 - accuracy: 1.0000
# Epoch 9/50
#  - 1s - loss: 7.4344e-04 - accuracy: 1.0000
# Epoch 10/50
#  - 1s - loss: 5.3682e-04 - accuracy: 1.0000
# Epoch 11/50
#  - 1s - loss: 4.0513e-04 - accuracy: 1.0000
# Epoch 12/50
#  - 1s - loss: 3.1669e-04 - accuracy: 1.0000
# Epoch 13/50
#  - 1s - loss: 2.5449e-04 - accuracy: 1.0000
# Epoch 14/50
#  - 1s - loss: 2.0932e-04 - accuracy: 1.0000
# Epoch 15/50
#  - 1s - loss: 1.7494e-04 - accuracy: 1.0000
# Epoch 16/50
#  - 1s - loss: 1.4810e-04 - accuracy: 1.0000
# Epoch 17/50
#  - 1s - loss: 1.2688e-04 - accuracy: 1.0000
# Epoch 18/50
#  - 1s - loss: 1.0998e-04 - accuracy: 1.0000
# Epoch 19/50
#  - 1s - loss: 9.6036e-05 - accuracy: 1.0000
# Epoch 20/50
#  - 1s - loss: 8.4614e-05 - accuracy: 1.0000
# Epoch 21/50
#  - 1s - loss: 7.4935e-05 - accuracy: 1.0000
# Epoch 22/50
#  - 1s - loss: 6.6928e-05 - accuracy: 1.0000
# Epoch 23/50
#  - 1s - loss: 6.0124e-05 - accuracy: 1.0000
# Epoch 24/50
#  - 1s - loss: 5.4215e-05 - accuracy: 1.0000
# Epoch 25/50
#  - 1s - loss: 4.9115e-05 - accuracy: 1.0000
# Epoch 26/50
#  - 1s - loss: 4.4687e-05 - accuracy: 1.0000
# Epoch 27/50
#  - 1s - loss: 4.0768e-05 - accuracy: 1.0000
# Epoch 28/50
#  - 1s - loss: 3.7371e-05 - accuracy: 1.0000
# Epoch 29/50
#  - 1s - loss: 3.4352e-05 - accuracy: 1.0000
# Epoch 30/50
#  - 1s - loss: 3.1675e-05 - accuracy: 1.0000
# Epoch 31/50
#  - 1s - loss: 2.9223e-05 - accuracy: 1.0000
# Epoch 32/50
#  - 1s - loss: 2.7085e-05 - accuracy: 1.0000
# Epoch 33/50
#  - 1s - loss: 2.5125e-05 - accuracy: 1.0000
# Epoch 34/50
#  - 1s - loss: 2.3381e-05 - accuracy: 1.0000
# Epoch 35/50
#  - 1s - loss: 2.1758e-05 - accuracy: 1.0000
# Epoch 36/50
#  - 1s - loss: 2.0297e-05 - accuracy: 1.0000
# Epoch 37/50
#  - 1s - loss: 1.8976e-05 - accuracy: 1.0000
# Epoch 38/50
#  - 1s - loss: 1.7763e-05 - accuracy: 1.0000
# Epoch 39/50
#  - 1s - loss: 1.6647e-05 - accuracy: 1.0000
# Epoch 40/50
#  - 1s - loss: 1.5619e-05 - accuracy: 1.0000
# Epoch 41/50
#  - 1s - loss: 1.4689e-05 - accuracy: 1.0000
# Epoch 42/50
#  - 1s - loss: 1.3814e-05 - accuracy: 1.0000
# Epoch 43/50
#  - 1s - loss: 1.3024e-05 - accuracy: 1.0000
# Epoch 44/50
#  - 1s - loss: 1.2305e-05 - accuracy: 1.0000
# Epoch 45/50
#  - 1s - loss: 1.1594e-05 - accuracy: 1.0000
# Epoch 46/50
#  - 1s - loss: 1.0958e-05 - accuracy: 1.0000
# Epoch 47/50
#  - 1s - loss: 1.0368e-05 - accuracy: 1.0000
# Epoch 48/50
#  - 1s - loss: 9.8422e-06 - accuracy: 1.0000
# Epoch 49/50
#  - 1s - loss: 9.3094e-06 - accuracy: 1.0000
# Epoch 50/50
#  - 1s - loss: 8.8345e-06 - accuracy: 1.0000
# 12 accuracy: 0.9200000166893005
# Epoch 1/50
#  - 1s - loss: 0.4655 - accuracy: 0.7856
# Epoch 2/50
#  - 1s - loss: 0.0563 - accuracy: 0.9939
# Epoch 3/50
#  - 1s - loss: 0.0157 - accuracy: 1.0000
# Epoch 4/50
#  - 1s - loss: 0.0074 - accuracy: 1.0000
# Epoch 5/50
#  - 1s - loss: 0.0040 - accuracy: 1.0000
# Epoch 6/50
#  - 1s - loss: 0.0023 - accuracy: 1.0000
# Epoch 7/50
#  - 1s - loss: 0.0015 - accuracy: 1.0000
# Epoch 8/50
#  - 1s - loss: 0.0010 - accuracy: 1.0000
# Epoch 9/50
#  - 1s - loss: 7.7037e-04 - accuracy: 1.0000
# Epoch 10/50
#  - 1s - loss: 5.9350e-04 - accuracy: 1.0000
# Epoch 11/50
#  - 1s - loss: 4.7084e-04 - accuracy: 1.0000
# Epoch 12/50
#  - 1s - loss: 3.8448e-04 - accuracy: 1.0000
# Epoch 13/50
#  - 1s - loss: 3.1779e-04 - accuracy: 1.0000
# Epoch 14/50
#  - 1s - loss: 2.6761e-04 - accuracy: 1.0000
# Epoch 15/50
#  - 1s - loss: 2.2926e-04 - accuracy: 1.0000
# Epoch 16/50
#  - 1s - loss: 1.9742e-04 - accuracy: 1.0000
# Epoch 17/50
#  - 1s - loss: 1.7194e-04 - accuracy: 1.0000
# Epoch 18/50
#  - 1s - loss: 1.5105e-04 - accuracy: 1.0000
# Epoch 19/50
#  - 1s - loss: 1.3406e-04 - accuracy: 1.0000
# Epoch 20/50
#  - 1s - loss: 1.1926e-04 - accuracy: 1.0000
# Epoch 21/50
#  - 1s - loss: 1.0712e-04 - accuracy: 1.0000
# Epoch 22/50
#  - 1s - loss: 9.6315e-05 - accuracy: 1.0000
# Epoch 23/50
#  - 1s - loss: 8.7224e-05 - accuracy: 1.0000
# Epoch 24/50
#  - 1s - loss: 7.9257e-05 - accuracy: 1.0000
# Epoch 25/50
#  - 1s - loss: 7.2277e-05 - accuracy: 1.0000
# Epoch 26/50
#  - 1s - loss: 6.6123e-05 - accuracy: 1.0000
# Epoch 27/50
#  - 1s - loss: 6.0905e-05 - accuracy: 1.0000
# Epoch 28/50
#  - 1s - loss: 5.5943e-05 - accuracy: 1.0000
# Epoch 29/50
#  - 1s - loss: 5.1599e-05 - accuracy: 1.0000
# Epoch 30/50
#  - 1s - loss: 4.7760e-05 - accuracy: 1.0000
# Epoch 31/50
#  - 1s - loss: 4.4315e-05 - accuracy: 1.0000
# Epoch 32/50
#  - 1s - loss: 4.1175e-05 - accuracy: 1.0000
# Epoch 33/50
#  - 1s - loss: 3.8322e-05 - accuracy: 1.0000
# Epoch 34/50
#  - 1s - loss: 3.5860e-05 - accuracy: 1.0000
# Epoch 35/50
#  - 1s - loss: 3.3374e-05 - accuracy: 1.0000
# Epoch 36/50
#  - 1s - loss: 3.1220e-05 - accuracy: 1.0000
# Epoch 37/50
#  - 1s - loss: 2.9283e-05 - accuracy: 1.0000
# Epoch 38/50
#  - 1s - loss: 2.7458e-05 - accuracy: 1.0000
# Epoch 39/50
#  - 1s - loss: 2.5225e-05 - accuracy: 1.0000
# Epoch 40/50
#  - 1s - loss: 2.3191e-05 - accuracy: 1.0000
# Epoch 41/50
#  - 1s - loss: 2.1936e-05 - accuracy: 1.0000
# Epoch 42/50
#  - 1s - loss: 2.0709e-05 - accuracy: 1.0000
# Epoch 43/50
#  - 1s - loss: 1.9601e-05 - accuracy: 1.0000
# Epoch 44/50
#  - 1s - loss: 1.8567e-05 - accuracy: 1.0000
# Epoch 45/50
#  - 1s - loss: 1.7615e-05 - accuracy: 1.0000
# Epoch 46/50
#  - 1s - loss: 1.6706e-05 - accuracy: 1.0000
# Epoch 47/50
#  - 1s - loss: 1.5857e-05 - accuracy: 1.0000
# Epoch 48/50
#  - 1s - loss: 1.5073e-05 - accuracy: 1.0000
# Epoch 49/50
#  - 1s - loss: 1.4323e-05 - accuracy: 1.0000
# Epoch 50/50
#  - 1s - loss: 1.3636e-05 - accuracy: 1.0000
# 13 accuracy: 0.9200000166893005
# Epoch 1/50
#  - 1s - loss: 0.4640 - accuracy: 0.7828
# Epoch 2/50
#  - 1s - loss: 0.0552 - accuracy: 0.9950
# Epoch 3/50
#  - 1s - loss: 0.0155 - accuracy: 1.0000
# Epoch 4/50
#  - 1s - loss: 0.0072 - accuracy: 1.0000
# Epoch 5/50
#  - 1s - loss: 0.0039 - accuracy: 1.0000
# Epoch 6/50
#  - 1s - loss: 0.0024 - accuracy: 1.0000
# Epoch 7/50
#  - 1s - loss: 0.0016 - accuracy: 1.0000
# Epoch 8/50
#  - 1s - loss: 0.0011 - accuracy: 1.0000
# Epoch 9/50
#  - 1s - loss: 8.0857e-04 - accuracy: 1.0000
# Epoch 10/50
#  - 1s - loss: 6.1764e-04 - accuracy: 1.0000
# Epoch 11/50
#  - 1s - loss: 4.8823e-04 - accuracy: 1.0000
# Epoch 12/50
#  - 1s - loss: 3.9304e-04 - accuracy: 1.0000
# Epoch 13/50
#  - 1s - loss: 3.2065e-04 - accuracy: 1.0000
# Epoch 14/50
#  - 1s - loss: 2.6818e-04 - accuracy: 1.0000
# Epoch 15/50
#  - 1s - loss: 2.2671e-04 - accuracy: 1.0000
# Epoch 16/50
#  - 1s - loss: 1.9435e-04 - accuracy: 1.0000
# Epoch 17/50
#  - 1s - loss: 1.6828e-04 - accuracy: 1.0000
# Epoch 18/50
#  - 1s - loss: 1.4671e-04 - accuracy: 1.0000
# Epoch 19/50
#  - 1s - loss: 1.2840e-04 - accuracy: 1.0000
# Epoch 20/50
#  - 1s - loss: 1.1287e-04 - accuracy: 1.0000
# Epoch 21/50
#  - 1s - loss: 9.9466e-05 - accuracy: 1.0000
# Epoch 22/50
#  - 1s - loss: 8.8245e-05 - accuracy: 1.0000
# Epoch 23/50
#  - 1s - loss: 7.8571e-05 - accuracy: 1.0000
# Epoch 24/50
#  - 1s - loss: 7.0410e-05 - accuracy: 1.0000
# Epoch 25/50
#  - 1s - loss: 6.3438e-05 - accuracy: 1.0000
# Epoch 26/50
#  - 1s - loss: 5.7320e-05 - accuracy: 1.0000
# Epoch 27/50
#  - 1s - loss: 5.1987e-05 - accuracy: 1.0000
# Epoch 28/50
#  - 1s - loss: 4.7388e-05 - accuracy: 1.0000
# Epoch 29/50
#  - 1s - loss: 4.3367e-05 - accuracy: 1.0000
# Epoch 30/50
#  - 1s - loss: 3.9771e-05 - accuracy: 1.0000
# Epoch 31/50
#  - 1s - loss: 3.6586e-05 - accuracy: 1.0000
# Epoch 32/50
#  - 1s - loss: 3.3768e-05 - accuracy: 1.0000
# Epoch 33/50
#  - 1s - loss: 3.1205e-05 - accuracy: 1.0000
# Epoch 34/50
#  - 1s - loss: 2.8955e-05 - accuracy: 1.0000
# Epoch 35/50
#  - 1s - loss: 2.6875e-05 - accuracy: 1.0000
# Epoch 36/50
#  - 1s - loss: 2.5004e-05 - accuracy: 1.0000
# Epoch 37/50
#  - 1s - loss: 2.3305e-05 - accuracy: 1.0000
# Epoch 38/50
#  - 1s - loss: 2.1770e-05 - accuracy: 1.0000
# Epoch 39/50
#  - 1s - loss: 2.0343e-05 - accuracy: 1.0000
# Epoch 40/50
#  - 1s - loss: 1.9045e-05 - accuracy: 1.0000
# Epoch 41/50
#  - 1s - loss: 1.7897e-05 - accuracy: 1.0000
# Epoch 42/50
#  - 1s - loss: 1.6782e-05 - accuracy: 1.0000
# Epoch 43/50
#  - 1s - loss: 1.5790e-05 - accuracy: 1.0000
# Epoch 44/50
#  - 1s - loss: 1.4861e-05 - accuracy: 1.0000
# Epoch 45/50
#  - 1s - loss: 1.4000e-05 - accuracy: 1.0000
# Epoch 46/50
#  - 1s - loss: 1.3214e-05 - accuracy: 1.0000
# Epoch 47/50
#  - 1s - loss: 1.2470e-05 - accuracy: 1.0000
# Epoch 48/50
#  - 1s - loss: 1.1788e-05 - accuracy: 1.0000
# Epoch 49/50
#  - 1s - loss: 1.1150e-05 - accuracy: 1.0000
# Epoch 50/50
#  - 1s - loss: 1.0558e-05 - accuracy: 1.0000
# 14 accuracy: 0.9200000166893005
# Epoch 1/50
#  - 1s - loss: 0.4833 - accuracy: 0.7772
# Epoch 2/50
#  - 1s - loss: 0.0675 - accuracy: 0.9906
# Epoch 3/50
#  - 1s - loss: 0.0172 - accuracy: 1.0000
# Epoch 4/50
#  - 1s - loss: 0.0072 - accuracy: 1.0000
# Epoch 5/50
#  - 1s - loss: 0.0034 - accuracy: 1.0000
# Epoch 6/50
#  - 1s - loss: 0.0020 - accuracy: 1.0000
# Epoch 7/50
#  - 1s - loss: 0.0013 - accuracy: 1.0000
# Epoch 8/50
#  - 1s - loss: 9.2805e-04 - accuracy: 1.0000
# Epoch 9/50
#  - 1s - loss: 6.9598e-04 - accuracy: 1.0000
# Epoch 10/50
#  - 1s - loss: 5.4652e-04 - accuracy: 1.0000
# Epoch 11/50
#  - 1s - loss: 4.3822e-04 - accuracy: 1.0000
# Epoch 12/50
#  - 1s - loss: 3.5947e-04 - accuracy: 1.0000
# Epoch 13/50
#  - 1s - loss: 3.0020e-04 - accuracy: 1.0000
# Epoch 14/50
#  - 1s - loss: 2.5425e-04 - accuracy: 1.0000
# Epoch 15/50
#  - 1s - loss: 2.1769e-04 - accuracy: 1.0000
# Epoch 16/50
#  - 1s - loss: 1.8810e-04 - accuracy: 1.0000
# Epoch 17/50
#  - 1s - loss: 1.6445e-04 - accuracy: 1.0000
# Epoch 18/50
#  - 1s - loss: 1.4476e-04 - accuracy: 1.0000
# Epoch 19/50
#  - 1s - loss: 1.2831e-04 - accuracy: 1.0000
# Epoch 20/50
#  - 1s - loss: 1.1452e-04 - accuracy: 1.0000
# Epoch 21/50
#  - 1s - loss: 1.0275e-04 - accuracy: 1.0000
# Epoch 22/50
#  - 1s - loss: 9.2543e-05 - accuracy: 1.0000
# Epoch 23/50
#  - 1s - loss: 8.3800e-05 - accuracy: 1.0000
# Epoch 24/50
#  - 1s - loss: 7.6031e-05 - accuracy: 1.0000
# Epoch 25/50
#  - 1s - loss: 6.9492e-05 - accuracy: 1.0000
# Epoch 26/50
#  - 1s - loss: 6.3425e-05 - accuracy: 1.0000
# Epoch 27/50
#  - 1s - loss: 5.8228e-05 - accuracy: 1.0000
# Epoch 28/50
#  - 1s - loss: 5.3597e-05 - accuracy: 1.0000
# Epoch 29/50
#  - 1s - loss: 4.9402e-05 - accuracy: 1.0000
# Epoch 30/50
#  - 1s - loss: 4.4004e-05 - accuracy: 1.0000
# Epoch 31/50
#  - 1s - loss: 4.0569e-05 - accuracy: 1.0000
# Epoch 32/50
#  - 1s - loss: 3.7819e-05 - accuracy: 1.0000
# Epoch 33/50
#  - 1s - loss: 3.5279e-05 - accuracy: 1.0000
# Epoch 34/50
#  - 1s - loss: 3.3028e-05 - accuracy: 1.0000
# Epoch 35/50
#  - 1s - loss: 3.0859e-05 - accuracy: 1.0000
# Epoch 36/50
#  - 1s - loss: 2.8954e-05 - accuracy: 1.0000
# Epoch 37/50
#  - 1s - loss: 2.7187e-05 - accuracy: 1.0000
# Epoch 38/50
#  - 1s - loss: 2.5557e-05 - accuracy: 1.0000
# Epoch 39/50
#  - 1s - loss: 2.4053e-05 - accuracy: 1.0000
# Epoch 40/50
#  - 1s - loss: 2.2678e-05 - accuracy: 1.0000
# Epoch 41/50
#  - 1s - loss: 2.1368e-05 - accuracy: 1.0000
# Epoch 42/50
#  - 1s - loss: 2.0158e-05 - accuracy: 1.0000
# Epoch 43/50
#  - 1s - loss: 1.9047e-05 - accuracy: 1.0000
# Epoch 44/50
#  - 1s - loss: 1.8025e-05 - accuracy: 1.0000
# Epoch 45/50
#  - 1s - loss: 1.7073e-05 - accuracy: 1.0000
# Epoch 46/50
#  - 1s - loss: 1.6178e-05 - accuracy: 1.0000
# Epoch 47/50
#  - 1s - loss: 1.5321e-05 - accuracy: 1.0000
# Epoch 48/50
#  - 1s - loss: 1.4561e-05 - accuracy: 1.0000
# Epoch 49/50
#  - 1s - loss: 1.3818e-05 - accuracy: 1.0000
# Epoch 50/50
#  - 1s - loss: 1.3125e-05 - accuracy: 1.0000
# 15 accuracy: 0.9150000214576721
# Epoch 1/50
#  - 1s - loss: 0.4829 - accuracy: 0.7878
# Epoch 2/50
#  - 1s - loss: 0.0649 - accuracy: 0.9922
# Epoch 3/50
#  - 1s - loss: 0.0185 - accuracy: 1.0000
# Epoch 4/50
#  - 1s - loss: 0.0080 - accuracy: 1.0000
# Epoch 5/50
#  - 1s - loss: 0.0042 - accuracy: 1.0000
# Epoch 6/50
#  - 1s - loss: 0.0024 - accuracy: 1.0000
# Epoch 7/50
#  - 1s - loss: 0.0015 - accuracy: 1.0000
# Epoch 8/50
#  - 1s - loss: 9.8655e-04 - accuracy: 1.0000
# Epoch 9/50
#  - 1s - loss: 7.1232e-04 - accuracy: 1.0000
# Epoch 10/50
#  - 1s - loss: 5.4110e-04 - accuracy: 1.0000
# Epoch 11/50
#  - 1s - loss: 4.2509e-04 - accuracy: 1.0000
# Epoch 12/50
#  - 1s - loss: 3.4488e-04 - accuracy: 1.0000
# Epoch 13/50
#  - 1s - loss: 2.8524e-04 - accuracy: 1.0000
# Epoch 14/50
#  - 1s - loss: 2.4059e-04 - accuracy: 1.0000
# Epoch 15/50
#  - 1s - loss: 2.0557e-04 - accuracy: 1.0000
# Epoch 16/50
#  - 1s - loss: 1.7777e-04 - accuracy: 1.0000
# Epoch 17/50
#  - 1s - loss: 1.5516e-04 - accuracy: 1.0000
# Epoch 18/50
#  - 1s - loss: 1.3663e-04 - accuracy: 1.0000
# Epoch 19/50
#  - 1s - loss: 1.2150e-04 - accuracy: 1.0000
# Epoch 20/50
#  - 1s - loss: 1.0818e-04 - accuracy: 1.0000
# Epoch 21/50
#  - 1s - loss: 9.7076e-05 - accuracy: 1.0000
# Epoch 22/50
#  - 1s - loss: 8.7433e-05 - accuracy: 1.0000
# Epoch 23/50
#  - 1s - loss: 7.7967e-05 - accuracy: 1.0000
# Epoch 24/50
#  - 1s - loss: 6.9624e-05 - accuracy: 1.0000
# Epoch 25/50
#  - 1s - loss: 6.1961e-05 - accuracy: 1.0000
# Epoch 26/50
#  - 1s - loss: 5.4780e-05 - accuracy: 1.0000
# Epoch 27/50
#  - 1s - loss: 4.8456e-05 - accuracy: 1.0000
# Epoch 28/50
#  - 1s - loss: 4.2759e-05 - accuracy: 1.0000
# Epoch 29/50
#  - 1s - loss: 3.7719e-05 - accuracy: 1.0000
# Epoch 30/50
#  - 1s - loss: 3.3440e-05 - accuracy: 1.0000
# Epoch 31/50
#  - 1s - loss: 2.9694e-05 - accuracy: 1.0000
# Epoch 32/50
#  - 1s - loss: 2.6517e-05 - accuracy: 1.0000
# Epoch 33/50
#  - 1s - loss: 2.3694e-05 - accuracy: 1.0000
# Epoch 34/50
#  - 1s - loss: 2.1338e-05 - accuracy: 1.0000
# Epoch 35/50
#  - 1s - loss: 1.9277e-05 - accuracy: 1.0000
# Epoch 36/50
#  - 1s - loss: 1.7488e-05 - accuracy: 1.0000
# Epoch 37/50
#  - 1s - loss: 1.5948e-05 - accuracy: 1.0000
# Epoch 38/50
#  - 1s - loss: 1.4596e-05 - accuracy: 1.0000
# Epoch 39/50
#  - 1s - loss: 1.3390e-05 - accuracy: 1.0000
# Epoch 40/50
#  - 1s - loss: 1.2327e-05 - accuracy: 1.0000
# Epoch 41/50
#  - 1s - loss: 1.1383e-05 - accuracy: 1.0000
# Epoch 42/50
#  - 1s - loss: 1.0541e-05 - accuracy: 1.0000
# Epoch 43/50
#  - 1s - loss: 9.7902e-06 - accuracy: 1.0000
# Epoch 44/50
#  - 1s - loss: 9.0976e-06 - accuracy: 1.0000
# Epoch 45/50
#  - 1s - loss: 8.4805e-06 - accuracy: 1.0000
# Epoch 46/50
#  - 1s - loss: 7.9195e-06 - accuracy: 1.0000
# Epoch 47/50
#  - 1s - loss: 7.4080e-06 - accuracy: 1.0000
# Epoch 48/50
#  - 1s - loss: 6.9369e-06 - accuracy: 1.0000
# Epoch 49/50
#  - 1s - loss: 6.5138e-06 - accuracy: 1.0000
# Epoch 50/50
#  - 1s - loss: 6.1294e-06 - accuracy: 1.0000
# 16 accuracy: 0.9100000262260437
# Epoch 1/50
#  - 1s - loss: 0.4744 - accuracy: 0.7789
# Epoch 2/50
#  - 1s - loss: 0.0631 - accuracy: 0.9944
# Epoch 3/50
#  - 1s - loss: 0.0185 - accuracy: 1.0000
# Epoch 4/50
#  - 1s - loss: 0.0086 - accuracy: 1.0000
# Epoch 5/50
#  - 1s - loss: 0.0046 - accuracy: 1.0000
# Epoch 6/50
#  - 1s - loss: 0.0027 - accuracy: 1.0000
# Epoch 7/50
#  - 1s - loss: 0.0018 - accuracy: 1.0000
# Epoch 8/50
#  - 1s - loss: 0.0012 - accuracy: 1.0000
# Epoch 9/50
#  - 1s - loss: 9.2461e-04 - accuracy: 1.0000
# Epoch 10/50
#  - 1s - loss: 7.1515e-04 - accuracy: 1.0000
# Epoch 11/50
#  - 1s - loss: 5.7159e-04 - accuracy: 1.0000
# Epoch 12/50
#  - 1s - loss: 4.6615e-04 - accuracy: 1.0000
# Epoch 13/50
#  - 1s - loss: 3.8805e-04 - accuracy: 1.0000
# Epoch 14/50
#  - 1s - loss: 3.2767e-04 - accuracy: 1.0000
# Epoch 15/50
#  - 1s - loss: 2.8004e-04 - accuracy: 1.0000
# Epoch 16/50
#  - 1s - loss: 2.4313e-04 - accuracy: 1.0000
# Epoch 17/50
#  - 1s - loss: 2.1185e-04 - accuracy: 1.0000
# Epoch 18/50
#  - 1s - loss: 1.8608e-04 - accuracy: 1.0000
# Epoch 19/50
#  - 1s - loss: 1.6512e-04 - accuracy: 1.0000
# Epoch 20/50
#  - 1s - loss: 1.4701e-04 - accuracy: 1.0000
# Epoch 21/50
#  - 1s - loss: 1.3191e-04 - accuracy: 1.0000
# Epoch 22/50
#  - 1s - loss: 1.1900e-04 - accuracy: 1.0000
# Epoch 23/50
#  - 1s - loss: 1.0777e-04 - accuracy: 1.0000
# Epoch 24/50
#  - 1s - loss: 9.8838e-05 - accuracy: 1.0000
# Epoch 25/50
#  - 1s - loss: 8.9432e-05 - accuracy: 1.0000
# Epoch 26/50
#  - 1s - loss: 8.1873e-05 - accuracy: 1.0000
# Epoch 27/50
#  - 1s - loss: 7.5249e-05 - accuracy: 1.0000
# Epoch 28/50
#  - 1s - loss: 6.9346e-05 - accuracy: 1.0000
# Epoch 29/50
#  - 1s - loss: 6.4077e-05 - accuracy: 1.0000
# Epoch 30/50
#  - 1s - loss: 5.9447e-05 - accuracy: 1.0000
# Epoch 31/50
#  - 1s - loss: 5.5151e-05 - accuracy: 1.0000
# Epoch 32/50
#  - 1s - loss: 5.1287e-05 - accuracy: 1.0000
# Epoch 33/50
#  - 1s - loss: 4.7858e-05 - accuracy: 1.0000
# Epoch 34/50
#  - 1s - loss: 4.4551e-05 - accuracy: 1.0000
# Epoch 35/50
#  - 1s - loss: 4.1629e-05 - accuracy: 1.0000
# Epoch 36/50
#  - 1s - loss: 3.9005e-05 - accuracy: 1.0000
# Epoch 37/50
#  - 1s - loss: 3.6567e-05 - accuracy: 1.0000
# Epoch 38/50
#  - 1s - loss: 3.3507e-05 - accuracy: 1.0000
# Epoch 39/50
#  - 1s - loss: 3.1470e-05 - accuracy: 1.0000
# Epoch 40/50
#  - 1s - loss: 2.9676e-05 - accuracy: 1.0000
# Epoch 41/50
#  - 1s - loss: 2.8006e-05 - accuracy: 1.0000
# Epoch 42/50
#  - 1s - loss: 2.6466e-05 - accuracy: 1.0000
# Epoch 43/50
#  - 1s - loss: 2.5039e-05 - accuracy: 1.0000
# Epoch 44/50
#  - 1s - loss: 2.3700e-05 - accuracy: 1.0000
# Epoch 45/50
#  - 1s - loss: 2.2461e-05 - accuracy: 1.0000
# Epoch 46/50
#  - 1s - loss: 2.1310e-05 - accuracy: 1.0000
# Epoch 47/50
#  - 1s - loss: 2.0237e-05 - accuracy: 1.0000
# Epoch 48/50
#  - 1s - loss: 1.9222e-05 - accuracy: 1.0000
# Epoch 49/50
#  - 1s - loss: 1.8275e-05 - accuracy: 1.0000
# Epoch 50/50
#  - 1s - loss: 1.7413e-05 - accuracy: 1.0000
# 17 accuracy: 0.925000011920929
# Epoch 1/50
#  - 1s - loss: 0.5040 - accuracy: 0.7489
# Epoch 2/50
#  - 1s - loss: 0.0786 - accuracy: 0.9883
# Epoch 3/50
#  - 1s - loss: 0.0191 - accuracy: 1.0000
# Epoch 4/50
#  - 1s - loss: 0.0083 - accuracy: 1.0000
# Epoch 5/50
#  - 1s - loss: 0.0042 - accuracy: 1.0000
# Epoch 6/50
#  - 1s - loss: 0.0023 - accuracy: 1.0000
# Epoch 7/50
#  - 1s - loss: 0.0014 - accuracy: 1.0000
# Epoch 8/50
#  - 1s - loss: 9.4254e-04 - accuracy: 1.0000
# Epoch 9/50
#  - 1s - loss: 6.7600e-04 - accuracy: 1.0000
# Epoch 10/50
#  - 1s - loss: 5.0908e-04 - accuracy: 1.0000
# Epoch 11/50
# ...
# Epoch 5/50
#  - 1s - loss: 0.6048 - accuracy: 0.9278
# Epoch 6/50
#  - 1s - loss: 0.5666 - accuracy: 0.9428
# Epoch 7/50
#  - 1s - loss: 0.5270 - accuracy: 0.9456
# Epoch 8/50
#  - 1s - loss: 0.4849 - accuracy: 0.9550
# Epoch 9/50
#  - 1s - loss: 0.4452 - accuracy: 0.9611
# Epoch 10/50
#  - 1s - loss: 0.4061 - accuracy: 0.9639
# Epoch 11/50
#  - 1s - loss: 0.3691 - accuracy: 0.9672
# Epoch 12/50
#  - 1s - loss: 0.3358 - accuracy: 0.9733
# Epoch 13/50
#  - 1s - loss: 0.3058 - accuracy: 0.9767
# Epoch 14/50
#  - 1s - loss: 0.2777 - accuracy: 0.9822
# Epoch 15/50
#  - 1s - loss: 0.2526 - accuracy: 0.9850
# Epoch 16/50
#  - 1s - loss: 0.2296 - accuracy: 0.9867
# Epoch 17/50
#  - 1s - loss: 0.2093 - accuracy: 0.9883
# Epoch 18/50
#  - 1s - loss: 0.1914 - accuracy: 0.9900
# Epoch 19/50
#  - 1s - loss: 0.1745 - accuracy: 0.9922
# Epoch 20/50
#  - 1s - loss: 0.1593 - accuracy: 0.9928
# Epoch 21/50
#  - 1s - loss: 0.1461 - accuracy: 0.9933
# Epoch 22/50
#  - 1s - loss: 0.1335 - accuracy: 0.9956
# Epoch 23/50
#  - 1s - loss: 0.1228 - accuracy: 0.9967
# Epoch 24/50
#  - 1s - loss: 0.1129 - accuracy: 0.9972
# Epoch 25/50
#  - 1s - loss: 0.1039 - accuracy: 0.9978
# Epoch 26/50
#  - 1s - loss: 0.0956 - accuracy: 0.9989
# Epoch 27/50
#  - 1s - loss: 0.0880 - accuracy: 0.9989
# Epoch 28/50
#  - 1s - loss: 0.0815 - accuracy: 0.9994
# Epoch 29/50
#  - 1s - loss: 0.0755 - accuracy: 1.0000
# Epoch 30/50
#  - 1s - loss: 0.0697 - accuracy: 1.0000
# Epoch 31/50
#  - 1s - loss: 0.0645 - accuracy: 1.0000
# Epoch 32/50
#  - 1s - loss: 0.0599 - accuracy: 1.0000
# Epoch 33/50
#  - 1s - loss: 0.0556 - accuracy: 1.0000
# Epoch 34/50
#  - 1s - loss: 0.0517 - accuracy: 1.0000
# Epoch 35/50
#  - 1s - loss: 0.0481 - accuracy: 1.0000
# Epoch 36/50
#  - 1s - loss: 0.0449 - accuracy: 1.0000
# Epoch 37/50
#  - 1s - loss: 0.0419 - accuracy: 1.0000
# Epoch 38/50
#  - 1s - loss: 0.0392 - accuracy: 1.0000
# Epoch 39/50
#  - 1s - loss: 0.0367 - accuracy: 1.0000
# Epoch 40/50
#  - 1s - loss: 0.0343 - accuracy: 1.0000
# Epoch 41/50
#  - 1s - loss: 0.0320 - accuracy: 1.0000
# Epoch 42/50
#  - 1s - loss: 0.0300 - accuracy: 1.0000
# Epoch 43/50
#  - 1s - loss: 0.0282 - accuracy: 1.0000
# Epoch 44/50
#  - 1s - loss: 0.0265 - accuracy: 1.0000
# Epoch 45/50
#  - 1s - loss: 0.0249 - accuracy: 1.0000
# Epoch 46/50
#  - 1s - loss: 0.0235 - accuracy: 1.0000
# Epoch 47/50
#  - 1s - loss: 0.0221 - accuracy: 1.0000
# Epoch 48/50
#  - 1s - loss: 0.0208 - accuracy: 1.0000
# Epoch 49/50
#  - 1s - loss: 0.0196 - accuracy: 1.0000
# Epoch 50/50
#  - 1s - loss: 0.0186 - accuracy: 1.0000
# 25 accuracy: 0.9100000262260437
# Epoch 1/50
#  - 1s - loss: 0.6923 - accuracy: 0.5133
# Epoch 2/50
#  - 1s - loss: 0.6861 - accuracy: 0.5683
# Epoch 3/50
#  - 1s - loss: 0.6713 - accuracy: 0.6550
# Epoch 4/50
#  - 1s - loss: 0.6464 - accuracy: 0.8428
# Epoch 5/50
#  - 1s - loss: 0.6139 - accuracy: 0.9300
# Epoch 6/50
#  - 1s - loss: 0.5749 - accuracy: 0.9144
# Epoch 7/50
#  - 1s - loss: 0.5305 - accuracy: 0.9489
# Epoch 8/50
#  - 1s - loss: 0.4847 - accuracy: 0.9567
# Epoch 9/50
#  - 1s - loss: 0.4398 - accuracy: 0.9606
# Epoch 10/50
#  - 1s - loss: 0.3976 - accuracy: 0.9678
# Epoch 11/50
#  - 1s - loss: 0.3580 - accuracy: 0.9739
# Epoch 12/50
#  - 1s - loss: 0.3225 - accuracy: 0.9772
# Epoch 13/50
#  - 1s - loss: 0.2907 - accuracy: 0.9806
# Epoch 14/50
#  - 1s - loss: 0.2622 - accuracy: 0.9822
# Epoch 15/50
#  - 1s - loss: 0.2359 - accuracy: 0.9867
# Epoch 16/50
#  - 1s - loss: 0.2134 - accuracy: 0.9894
# Epoch 17/50
#  - 1s - loss: 0.1928 - accuracy: 0.9917
# Epoch 18/50
#  - 1s - loss: 0.1749 - accuracy: 0.9933
# Epoch 19/50
#  - 1s - loss: 0.1586 - accuracy: 0.9928
# Epoch 20/50
#  - 1s - loss: 0.1442 - accuracy: 0.9939
# Epoch 21/50
#  - 1s - loss: 0.1313 - accuracy: 0.9950
# Epoch 22/50
#  - 1s - loss: 0.1201 - accuracy: 0.9967
# Epoch 23/50
#  - 1s - loss: 0.1094 - accuracy: 0.9978
# Epoch 24/50
#  - 1s - loss: 0.1000 - accuracy: 0.9978
# Epoch 25/50
#  - 1s - loss: 0.0917 - accuracy: 0.9989
# Epoch 26/50
#  - 1s - loss: 0.0841 - accuracy: 0.9994
# Epoch 27/50
#  - 1s - loss: 0.0774 - accuracy: 0.9994
# Epoch 28/50
#  - 1s - loss: 0.0712 - accuracy: 1.0000
# Epoch 29/50
#  - 1s - loss: 0.0656 - accuracy: 1.0000
# Epoch 30/50
#  - 1s - loss: 0.0606 - accuracy: 1.0000
# Epoch 31/50
#  - 1s - loss: 0.0561 - accuracy: 1.0000
# Epoch 32/50
#  - 1s - loss: 0.0518 - accuracy: 1.0000
# Epoch 33/50
#  - 1s - loss: 0.0481 - accuracy: 1.0000
# Epoch 34/50
#  - 1s - loss: 0.0446 - accuracy: 1.0000
# Epoch 35/50
#  - 1s - loss: 0.0415 - accuracy: 1.0000
# Epoch 36/50
#  - 1s - loss: 0.0384 - accuracy: 1.0000
# Epoch 37/50
#  - 1s - loss: 0.0360 - accuracy: 1.0000
# Epoch 38/50
#  - 1s - loss: 0.0335 - accuracy: 1.0000
# Epoch 39/50
#  - 1s - loss: 0.0312 - accuracy: 1.0000
# Epoch 40/50
#  - 1s - loss: 0.0293 - accuracy: 1.0000
# Epoch 41/50
#  - 1s - loss: 0.0274 - accuracy: 1.0000
# Epoch 42/50
#  - 1s - loss: 0.0257 - accuracy: 1.0000
# Epoch 43/50
#  - 1s - loss: 0.0241 - accuracy: 1.0000
# Epoch 44/50
#  - 1s - loss: 0.0226 - accuracy: 1.0000
# Epoch 45/50
#  - 1s - loss: 0.0212 - accuracy: 1.0000
# Epoch 46/50
#  - 1s - loss: 0.0200 - accuracy: 1.0000
# Epoch 47/50
#  - 1s - loss: 0.0188 - accuracy: 1.0000
# Epoch 48/50
#  - 1s - loss: 0.0177 - accuracy: 1.0000
# Epoch 49/50
#  - 1s - loss: 0.0167 - accuracy: 1.0000
# Epoch 50/50
#  - 1s - loss: 0.0158 - accuracy: 1.0000
# 26 accuracy: 0.9100000262260437
# Epoch 1/50
#  - 1s - loss: 0.6919 - accuracy: 0.5678
# Epoch 2/50
#  - 1s - loss: 0.6829 - accuracy: 0.8578
# Epoch 3/50
#  - 1s - loss: 0.6638 - accuracy: 0.7106
# Epoch 4/50
#  - 1s - loss: 0.6363 - accuracy: 0.9044
# Epoch 5/50
#  - 1s - loss: 0.5986 - accuracy: 0.9383
# Epoch 6/50
#  - 1s - loss: 0.5577 - accuracy: 0.9350
# Epoch 7/50
#  - 1s - loss: 0.5106 - accuracy: 0.9450
# Epoch 8/50
#  - 1s - loss: 0.4647 - accuracy: 0.9544
# Epoch 9/50
#  - 1s - loss: 0.4214 - accuracy: 0.9600
# Epoch 10/50
#  - 1s - loss: 0.3796 - accuracy: 0.9644
# Epoch 11/50
#  - 1s - loss: 0.3415 - accuracy: 0.9694
# Epoch 12/50
#  - 1s - loss: 0.3068 - accuracy: 0.9761
# Epoch 13/50
#  - 1s - loss: 0.2762 - accuracy: 0.9800
# Epoch 14/50
#  - 1s - loss: 0.2482 - accuracy: 0.9844
# Epoch 15/50
#  - 1s - loss: 0.2237 - accuracy: 0.9883
# Epoch 16/50
#  - 1s - loss: 0.2015 - accuracy: 0.9883
# Epoch 17/50
#  - 1s - loss: 0.1822 - accuracy: 0.9906
# Epoch 18/50
#  - 1s - loss: 0.1647 - accuracy: 0.9928
# Epoch 19/50
#  - 1s - loss: 0.1493 - accuracy: 0.9944
# Epoch 20/50
#  - 1s - loss: 0.1355 - accuracy: 0.9956
# Epoch 21/50
#  - 1s - loss: 0.1229 - accuracy: 0.9956
# Epoch 22/50
#  - 1s - loss: 0.1120 - accuracy: 0.9972
# Epoch 23/50
#  - 1s - loss: 0.1021 - accuracy: 0.9978
# Epoch 24/50
#  - 1s - loss: 0.0931 - accuracy: 0.9978
# Epoch 25/50
#  - 1s - loss: 0.0853 - accuracy: 0.9983
# Epoch 26/50
#  - 1s - loss: 0.0785 - accuracy: 0.9983
# Epoch 27/50
#  - 1s - loss: 0.0717 - accuracy: 1.0000
# Epoch 28/50
#  - 1s - loss: 0.0658 - accuracy: 1.0000
# Epoch 29/50
#  - 1s - loss: 0.0607 - accuracy: 1.0000
# Epoch 30/50
#  - 1s - loss: 0.0558 - accuracy: 1.0000
# Epoch 31/50
#  - 1s - loss: 0.0516 - accuracy: 1.0000
# Epoch 32/50
#  - 1s - loss: 0.0477 - accuracy: 1.0000
# Epoch 33/50
#  - 1s - loss: 0.0442 - accuracy: 1.0000
# Epoch 34/50
#  - 1s - loss: 0.0408 - accuracy: 1.0000
# Epoch 35/50
#  - 1s - loss: 0.0380 - accuracy: 1.0000
# Epoch 36/50
#  - 1s - loss: 0.0353 - accuracy: 1.0000
# Epoch 37/50
#  - 1s - loss: 0.0329 - accuracy: 1.0000
# Epoch 38/50
#  - 1s - loss: 0.0306 - accuracy: 1.0000
# Epoch 39/50
#  - 1s - loss: 0.0286 - accuracy: 1.0000
# Epoch 40/50
#  - 1s - loss: 0.0268 - accuracy: 1.0000
# Epoch 41/50
#  - 1s - loss: 0.0250 - accuracy: 1.0000
# Epoch 42/50
#  - 1s - loss: 0.0234 - accuracy: 1.0000
# Epoch 43/50
#  - 1s - loss: 0.0219 - accuracy: 1.0000
# Epoch 44/50
#  - 1s - loss: 0.0207 - accuracy: 1.0000
# Epoch 45/50
#  - 1s - loss: 0.0195 - accuracy: 1.0000
# Epoch 46/50
#  - 1s - loss: 0.0182 - accuracy: 1.0000
# Epoch 47/50
#  - 1s - loss: 0.0171 - accuracy: 1.0000
# Epoch 48/50
#  - 1s - loss: 0.0162 - accuracy: 1.0000
# Epoch 49/50
#  - 1s - loss: 0.0152 - accuracy: 1.0000
# Epoch 50/50
#  - 1s - loss: 0.0144 - accuracy: 1.0000
# 27 accuracy: 0.9100000262260437
# Epoch 1/50
#  - 1s - loss: 0.6916 - accuracy: 0.5406
# Epoch 2/50
#  - 1s - loss: 0.6820 - accuracy: 0.7978
# Epoch 3/50
#  - 1s - loss: 0.6633 - accuracy: 0.9000
# Epoch 4/50
#  - 1s - loss: 0.6347 - accuracy: 0.8783
# Epoch 5/50
#  - 1s - loss: 0.5974 - accuracy: 0.9272
# Epoch 6/50
#  - 1s - loss: 0.5541 - accuracy: 0.9394
# Epoch 7/50
#  - 1s - loss: 0.5085 - accuracy: 0.9517
# Epoch 8/50
#  - 1s - loss: 0.4627 - accuracy: 0.9528
# Epoch 9/50
#  - 1s - loss: 0.4194 - accuracy: 0.9600
# Epoch 10/50
#  - 1s - loss: 0.3772 - accuracy: 0.9678
# Epoch 11/50
#  - 1s - loss: 0.3393 - accuracy: 0.9706
# Epoch 12/50
#  - 1s - loss: 0.3050 - accuracy: 0.9772
# Epoch 13/50
#  - 1s - loss: 0.2751 - accuracy: 0.9828
# Epoch 14/50
#  - 1s - loss: 0.2468 - accuracy: 0.9861
# Epoch 15/50
#  - 1s - loss: 0.2226 - accuracy: 0.9883
# Epoch 16/50
#  - 1s - loss: 0.2014 - accuracy: 0.9889
# Epoch 17/50
#  - 1s - loss: 0.1816 - accuracy: 0.9928
# Epoch 18/50
#  - 1s - loss: 0.1642 - accuracy: 0.9922
# Epoch 19/50
#  - 1s - loss: 0.1488 - accuracy: 0.9950
# Epoch 20/50
#  - 1s - loss: 0.1353 - accuracy: 0.9972
# Epoch 21/50
#  - 1s - loss: 0.1230 - accuracy: 0.9967
# Epoch 22/50
#  - 1s - loss: 0.1119 - accuracy: 0.9972
# Epoch 23/50
#  - 1s - loss: 0.1023 - accuracy: 0.9972
# Epoch 24/50
#  - 1s - loss: 0.0932 - accuracy: 0.9983
# Epoch 25/50
#  - 1s - loss: 0.0855 - accuracy: 0.9994
# Epoch 26/50
#  - 1s - loss: 0.0784 - accuracy: 0.9989
# Epoch 27/50
#  - 1s - loss: 0.0720 - accuracy: 0.9994
# Epoch 28/50
#  - 1s - loss: 0.0664 - accuracy: 1.0000
# Epoch 29/50
#  - 1s - loss: 0.0609 - accuracy: 1.0000
# Epoch 30/50
#  - 1s - loss: 0.0562 - accuracy: 1.0000
# Epoch 31/50
#  - 1s - loss: 0.0520 - accuracy: 1.0000
# Epoch 32/50
#  - 1s - loss: 0.0480 - accuracy: 1.0000
# Epoch 33/50
#  - 1s - loss: 0.0444 - accuracy: 1.0000
# Epoch 34/50
#  - 1s - loss: 0.0413 - accuracy: 1.0000
# Epoch 35/50
#  - 1s - loss: 0.0383 - accuracy: 1.0000
# Epoch 36/50
#  - 1s - loss: 0.0357 - accuracy: 1.0000
# Epoch 37/50
#  - 1s - loss: 0.0332 - accuracy: 1.0000
# Epoch 38/50
#  - 1s - loss: 0.0309 - accuracy: 1.0000
# Epoch 39/50
#  - 1s - loss: 0.0289 - accuracy: 1.0000
# Epoch 40/50
#  - 1s - loss: 0.0270 - accuracy: 1.0000
# Epoch 41/50
#  - 1s - loss: 0.0252 - accuracy: 1.0000
# Epoch 42/50
#  - 1s - loss: 0.0237 - accuracy: 1.0000
# Epoch 43/50
#  - 1s - loss: 0.0221 - accuracy: 1.0000
# Epoch 44/50
#  - 1s - loss: 0.0208 - accuracy: 1.0000
# Epoch 45/50
#  - 1s - loss: 0.0195 - accuracy: 1.0000
# Epoch 46/50
#  - 1s - loss: 0.0184 - accuracy: 1.0000
# Epoch 47/50
#  - 1s - loss: 0.0173 - accuracy: 1.0000
# Epoch 48/50
#  - 1s - loss: 0.0164 - accuracy: 1.0000
# Epoch 49/50
#  - 1s - loss: 0.0154 - accuracy: 1.0000
# Epoch 50/50
#  - 1s - loss: 0.0145 - accuracy: 1.0000
# 28 accuracy: 0.9049999713897705
# Epoch 1/50
#  - 1s - loss: 0.6916 - accuracy: 0.5422
# Epoch 2/50
#  - 1s - loss: 0.6823 - accuracy: 0.7233
# Epoch 3/50
#  - 1s - loss: 0.6649 - accuracy: 0.8600
# Epoch 4/50
#  - 1s - loss: 0.6372 - accuracy: 0.9167
# Epoch 5/50
#  - 1s - loss: 0.6019 - accuracy: 0.9239
# Epoch 6/50
#  - 1s - loss: 0.5612 - accuracy: 0.9406
# Epoch 7/50
#  - 1s - loss: 0.5169 - accuracy: 0.9439
# Epoch 8/50
#  - 1s - loss: 0.4721 - accuracy: 0.9517
# Epoch 9/50
#  - 1s - loss: 0.4297 - accuracy: 0.9583
# Epoch 10/50
#  - 1s - loss: 0.3882 - accuracy: 0.9617
# Epoch 11/50
#  - 1s - loss: 0.3508 - accuracy: 0.9678
# Epoch 12/50
#  - 1s - loss: 0.3160 - accuracy: 0.9756
# Epoch 13/50
#  - 1s - loss: 0.2852 - accuracy: 0.9794
# Epoch 14/50
#  - 1s - loss: 0.2572 - accuracy: 0.9844
# Epoch 15/50
#  - 1s - loss: 0.2326 - accuracy: 0.9861
# Epoch 16/50
#  - 1s - loss: 0.2102 - accuracy: 0.9889
# Epoch 17/50
#  - 1s - loss: 0.1905 - accuracy: 0.9906
# Epoch 18/50
#  - 1s - loss: 0.1724 - accuracy: 0.9928
# Epoch 19/50
#  - 1s - loss: 0.1560 - accuracy: 0.9933
# Epoch 20/50
#  - 1s - loss: 0.1425 - accuracy: 0.9933
# Epoch 21/50
#  - 1s - loss: 0.1299 - accuracy: 0.9956
# Epoch 22/50
#  - 1s - loss: 0.1180 - accuracy: 0.9961
# Epoch 23/50
#  - 1s - loss: 0.1078 - accuracy: 0.9972
# Epoch 24/50
#  - 1s - loss: 0.0986 - accuracy: 0.9978
# Epoch 25/50
#  - 1s - loss: 0.0901 - accuracy: 0.9983
# Epoch 26/50
#  - 1s - loss: 0.0827 - accuracy: 0.9989
# Epoch 27/50
#  - 1s - loss: 0.0760 - accuracy: 0.9994
# Epoch 28/50
#  - 1s - loss: 0.0702 - accuracy: 1.0000
# Epoch 29/50
#  - 1s - loss: 0.0646 - accuracy: 1.0000
# Epoch 30/50
#  - 1s - loss: 0.0595 - accuracy: 1.0000
# Epoch 31/50
#  - 1s - loss: 0.0550 - accuracy: 1.0000
# Epoch 32/50
#  - 1s - loss: 0.0508 - accuracy: 1.0000
# Epoch 33/50
#  - 1s - loss: 0.0472 - accuracy: 1.0000
# Epoch 34/50
#  - 1s - loss: 0.0437 - accuracy: 1.0000
# Epoch 35/50
#  - 1s - loss: 0.0406 - accuracy: 1.0000
# Epoch 36/50
#  - 1s - loss: 0.0378 - accuracy: 1.0000
# Epoch 37/50
#  - 1s - loss: 0.0351 - accuracy: 1.0000
# Epoch 38/50
#  - 1s - loss: 0.0328 - accuracy: 1.0000
# Epoch 39/50
#  - 1s - loss: 0.0305 - accuracy: 1.0000
# Epoch 40/50
#  - 1s - loss: 0.0286 - accuracy: 1.0000
# Epoch 41/50
#  - 1s - loss: 0.0267 - accuracy: 1.0000
# Epoch 42/50
#  - 1s - loss: 0.0250 - accuracy: 1.0000
# Epoch 43/50
#  - 1s - loss: 0.0235 - accuracy: 1.0000
# Epoch 44/50
#  - 1s - loss: 0.0220 - accuracy: 1.0000
# Epoch 45/50
#  - 1s - loss: 0.0207 - accuracy: 1.0000
# Epoch 46/50
#  - 1s - loss: 0.0195 - accuracy: 1.0000
# Epoch 47/50
#  - 1s - loss: 0.0183 - accuracy: 1.0000
# Epoch 48/50
#  - 1s - loss: 0.0173 - accuracy: 1.0000
# Epoch 49/50
#  - 1s - loss: 0.0162 - accuracy: 1.0000
# Epoch 50/50
#  - 1s - loss: 0.0153 - accuracy: 1.0000
# 29 accuracy: 0.9100000262260437
# Epoch 1/50
#  - 1s - loss: 0.6910 - accuracy: 0.6294
# Epoch 2/50
#  - 1s - loss: 0.6790 - accuracy: 0.8750
# Epoch 3/50
#  - 1s - loss: 0.6573 - accuracy: 0.8989
# Epoch 4/50
#  - 1s - loss: 0.6252 - accuracy: 0.9272
# Epoch 5/50
#  - 1s - loss: 0.5867 - accuracy: 0.9244
# Epoch 6/50
#  - 1s - loss: 0.5431 - accuracy: 0.9367
# Epoch 7/50
#  - 1s - loss: 0.4966 - accuracy: 0.9478
# Epoch 8/50
#  - 1s - loss: 0.4523 - accuracy: 0.9489
# Epoch 9/50
#  - 1s - loss: 0.4085 - accuracy: 0.9600
# Epoch 10/50
#  - 1s - loss: 0.3691 - accuracy: 0.9683
# Epoch 11/50
#  - 1s - loss: 0.3323 - accuracy: 0.9706
# Epoch 12/50
#  - 1s - loss: 0.2990 - accuracy: 0.9772
# Epoch 13/50
#  - 1s - loss: 0.2684 - accuracy: 0.9828
# Epoch 14/50
#  - 1s - loss: 0.2417 - accuracy: 0.9850
# Epoch 15/50
#  - 1s - loss: 0.2171 - accuracy: 0.9883
# Epoch 16/50
#  - 1s - loss: 0.1969 - accuracy: 0.9894
# Epoch 17/50
#  - 1s - loss: 0.1771 - accuracy: 0.9911
# Epoch 18/50
#  - 1s - loss: 0.1604 - accuracy: 0.9928
# Epoch 19/50
#  - 1s - loss: 0.1456 - accuracy: 0.9944
# Epoch 20/50
#  - 1s - loss: 0.1317 - accuracy: 0.9956
# Epoch 21/50
#  - 1s - loss: 0.1203 - accuracy: 0.9972
# Epoch 22/50
#  - 1s - loss: 0.1097 - accuracy: 0.9972
# Epoch 23/50
#  - 1s - loss: 0.0996 - accuracy: 0.9983
# Epoch 24/50
#  - 1s - loss: 0.0909 - accuracy: 0.9983
# Epoch 25/50
#  - 1s - loss: 0.0833 - accuracy: 0.9989
# Epoch 26/50
#  - 1s - loss: 0.0762 - accuracy: 1.0000
# Epoch 27/50
#  - 1s - loss: 0.0699 - accuracy: 1.0000
# Epoch 28/50
#  - 1s - loss: 0.0643 - accuracy: 1.0000
# Epoch 29/50
#  - 1s - loss: 0.0591 - accuracy: 1.0000
# Epoch 30/50
#  - 1s - loss: 0.0545 - accuracy: 1.0000
# Epoch 31/50
#  - 1s - loss: 0.0505 - accuracy: 1.0000
# Epoch 32/50
#  - 1s - loss: 0.0464 - accuracy: 1.0000
# Epoch 33/50
#  - 1s - loss: 0.0431 - accuracy: 1.0000
# Epoch 34/50
#  - 1s - loss: 0.0401 - accuracy: 1.0000
# Epoch 35/50
#  - 1s - loss: 0.0371 - accuracy: 1.0000
# Epoch 36/50
#  - 1s - loss: 0.0344 - accuracy: 1.0000
# Epoch 37/50
#  - 1s - loss: 0.0320 - accuracy: 1.0000
# Epoch 38/50
#  - 1s - loss: 0.0298 - accuracy: 1.0000
# Epoch 39/50
#  - 1s - loss: 0.0279 - accuracy: 1.0000
# Epoch 40/50
#  - 1s - loss: 0.0260 - accuracy: 1.0000
# Epoch 41/50
#  - 1s - loss: 0.0244 - accuracy: 1.0000
# Epoch 42/50
#  - 1s - loss: 0.0229 - accuracy: 1.0000
# Epoch 43/50
#  - 1s - loss: 0.0214 - accuracy: 1.0000
# Epoch 44/50
#  - 1s - loss: 0.0201 - accuracy: 1.0000
# Epoch 45/50
#  - 1s - loss: 0.0189 - accuracy: 1.0000
# Epoch 46/50
#  - 1s - loss: 0.0178 - accuracy: 1.0000
# Epoch 47/50
#  - 1s - loss: 0.0167 - accuracy: 1.0000
# Epoch 48/50
#  - 1s - loss: 0.0158 - accuracy: 1.0000
# Epoch 49/50
#  - 1s - loss: 0.0149 - accuracy: 1.0000
# Epoch 50/50
#  - 1s - loss: 0.0140 - accuracy: 1.0000
# 30 accuracy: 0.9150000214576721
#           binary      count      tfidf       freq
# count  30.000000  30.000000  30.000000  30.000000
# mean    0.920833   0.891000   0.861167   0.908833
# std     0.009105   0.009322   0.016331   0.002842
# min     0.905000   0.870000   0.830000   0.905000
# 25%     0.915000   0.885000   0.850000   0.905000
# 50%     0.920000   0.890000   0.860000   0.910000
# 75%     0.925000   0.900000   0.870000   0.910000
# max     0.940000   0.905000   0.900000   0.915000

# %%
# test positive text
text = 'Best movie ever!'
print(predict_sentiment(text, vocab, tokenizer, model))
# test negative text
text = 'This is a bad movie.'
print(predict_sentiment(text, vocab, tokenizer, model))
# Out:
# 1.0
# 0.0

# %%
# Out:
# 1/1 [==============================] - 0s 1ms/step
# [[0.98006564]]
# 1.0
# 1/1 [==============================] - 0s 1ms/step
# [[1.5453779e-07]]
# 0.0

# %%
t='Panipat is bad awful movie.'
t2='Border is good movie.'
tokens = clean_doc(t)
print(tokens)
# filter by vocab
tokens = [w for w in tokens if w in vocab]
print(tokens)
# convert to line
line = ' '.join(tokens)
print('Tokenized from Vocab: '+ line)
# encode
encoded = tokenizer.texts_to_matrix([line], mode='freq')
print(encoded)
# prediction
# Out:
# ['Panipat', 'bad', 'awful', 'movie']
# ['bad', 'awful', 'movie']
# Tokenized from Vocab: bad awful movie
# [[0. 0. 0. ... 0. 0. 0.]]

# %%
# yhat = model.predict(encoded, verbose=0)
# print("Class: {}".format(yhat))
print(model.predict(encoded, verbose=0))

# yproba = model.predict_proba(encoded, verbose=0)    
# print("probability: {}" .format(yproba))
print(model.predict_proba(encoded, verbose=0))

model.predict(encoded, verbose=0)
model.predict_proba(encoded, verbose=0)    
print(predict_sentiment(t, vocab, tokenizer, model))
print(predict_sentiment(t2, vocab, tokenizer, model))
# Out:
# [[3.1213265e-11]]
# [[3.1213265e-11]]

# %%
model.predict(encoded, verbose=0)==model.predict_proba(encoded, verbose=0)
# Out:
# 0.0
# 1.0

# %%
# Out:
# '/Users/vivek/My Folder/Learning/imdb_sentiment_project/review_polarity'

# %%
import pickle

# saving model
filename = 'finalized_model.sav'
pickle.dump(model, open(os.getcwd()+ '/'+filename, 'wb'))

# saving tokenizer
with open(os.getcwd()+'/tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# loading
with open('tokenizer.pickle', 'rb') as handle:
    tokenizer = pickle.load(handle)
    
# load the model from disk
loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.score(X_test, Y_test)
print(result)

# %%
os.getcwd()
# Out:
# '/Users/vivek/My Folder/Learning/imdb_sentiment_project/review_polarity'

# %%
from string import punctuation
from os import listdir
from collections import Counter
from nltk.corpus import stopwords
from keras.preprocessing.text import Tokenizer
 
# load doc into memory
def load_doc(filename):
	# open the file as read only
	file = open(filename, 'r')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text
 
# turn a doc into clean tokens
def clean_doc(doc):
	# split into tokens by white space
	tokens = doc.split()
	# remove punctuation from each token
	table = str.maketrans('', '', punctuation)
	tokens = [w.translate(table) for w in tokens]
	# remove remaining tokens that are not alphabetic
	tokens = [word for word in tokens if word.isalpha()]
	# filter out stop words
	stop_words = set(stopwords.words('english'))
	tokens = [w for w in tokens if not w in stop_words]
	# filter out short tokens
	tokens = [word for word in tokens if len(word) > 1]
	return tokens
 
# load doc, clean and return line of tokens
def doc_to_line(filename, vocab):
	# load the doc
	doc = load_doc(filename)
	# clean doc
	tokens = clean_doc(doc)
	# filter by vocab
	tokens = [w for w in tokens if w in vocab]
	return ' '.join(tokens)
 
# load all docs in a directory
def process_docs(directory, vocab, is_trian):
	lines = list()
	# walk through all files in the folder
	for filename in listdir(directory):
		# skip any reviews in the test set
		if is_trian and filename.startswith('cv9'):
			continue
		if not is_trian and not filename.startswith('cv9'):
			continue
		# create the full path of the file to open
		path = directory + '/' + filename
		# load and clean the doc
		line = doc_to_line(path, vocab)
		# add to list
		lines.append(line)
	return lines
 
# load the vocabulary
vocab_filename = 'vocab.txt'
vocab = load_doc(vocab_filename)
vocab = vocab.split()
vocab = set(vocab)
 
# load all training reviews
positive_lines = process_docs('txt_sentoken/pos', vocab, True)
negative_lines = process_docs('txt_sentoken/neg', vocab, True)
 
# create the tokenizer
tokenizer = Tokenizer()
# fit the tokenizer on the documents
docs = negative_lines + positive_lines
tokenizer.fit_on_texts(docs)
 
# encode training data set
Xtrain = tokenizer.texts_to_matrix(docs, mode='freq')
print(Xtrain.shape)
 
# load all test reviews
positive_lines = process_docs('txt_sentoken/pos', vocab, False)
negative_lines = process_docs('txt_sentoken/neg', vocab, False)
docs = negative_lines + positive_lines
# encode training data set
Xtest = tokenizer.texts_to_matrix(docs, mode='freq')
print(Xtest.shape)
# Out:
# (1800, 342)
# (200, 342)

# %%
print(type(vocab))
print(vocab)
# Out:
# <class 'set'>
# {'certainly', 'shakespeare', 'heather', 'tim', 'peaks', 'surprise', 'brought', 'menace', 'needs', 'direct', 'look', 'seems', 'investigate', 'ludicrous', 'kids', 'pages', 'violence', 'crowd', 'keeping', 'casper', 'acting', 'limit', 'saying', 'briefed', 'theres', 'world', 'british', 'turning', 'killer', 'carrot', 'another', 'log', 'really', 'london', 'identity', 'finger', 'theyre', 'crime', 'burton', 'much', 'film', 'block', 'interesting', 'victorianera', 'attempt', 'horribly', 'hollow', 'locals', 'goulds', 'thats', 'deming', 'words', 'ripper', 'riddle', 'childs', 'les', 'comparison', 'supporting', 'series', 'get', 'starting', 'whistling', 'helped', 'first', 'like', 'new', 'arriving', 'half', 'onto', 'brothers', 'nearly', 'killing', 'prague', 'sexuality', 'campbell', 'jack', 'scenes', 'find', 'street', 'sooty', 'londons', 'nervous', 'language', 'crack', 'upon', 'mis', 'indians', 'reasons', 'unfortunates', 'question', 'would', 'vertical', 'martin', 'never', 'blame', 'actually', 'surprising', 'big', 'medium', 'however', 'word', 'godley', 'superman', 'marilyn', 'allen', 'mid', 'coltrane', 'past', 'comic', 'mad', 'befriends', 'hughes', 'enough', 'time', 'twin', 'design', 'creepy', 'consist', 'good', 'joe', 'carwho', 'see', 'whitechapel', 'stiff', 'dalmatians', 'go', 'eddie', 'includes', 'handling', 'sense', 'funny', 'filthy', 'original', 'inspector', 'stomach', 'called', 'roles', 'prophetic', 'hidden', 'anyone', 'whole', 'blackandwhite', 'apes', 'carving', 'novel', 'dreamy', 'case', 'pales', 'gruesome', 'whores', 'ending', 'ably', 'little', 'slay', 'copper', 'ghost', 'adapted', 'alan', 'set', 'comments', 'precision', 'tries', 'features', 'love', 'richardson', 'yglesias', 'watchmen', 'ians', 'hayes', 'well', 'turns', 'irish', 'researched', 'star', 'jews', 'moore', 'planet', 'performance', 'almost', 'stumbling', 'one', 'content', 'violencegore', 'quell', 'flashbacks', 'michael', 'footnotes', 'simpsons', 'hell', 'crazy', 'committing', 'deftly', 'bad', 'abberline', 'though', 'dreariness', 'albert', 'cant', 'saw', 'opium', 'ii', 'oscar', 'think', 'manson', 'geniuses', 'great', 'surgeon', 'remind', 'music', 'point', 'drug', 'chooses', 'captures', 'made', 'top', 'johnny', 'dont', 'absinthe', 'watch', 'looks', 'behind', 'mysterious', 'violent', 'course', 'police', 'long', 'dreams', 'opened', 'place', 'named', 'depp', 'terry', 'getting', 'imagining', 'job', 'calls', 'wont', 'wasnt', 'dismiss', 'sleepy', 'profession', 'unique', 'holds', 'could', 'cinematographer', 'blow', 'thoroughly', 'color', 'surgical', 'acts', 'screenwriters', 'dark', 'itll', 'ghastly', 'secret', 'production', 'created', 'typically', 'thing', 'robbie', 'blindly', 'arthouse', 'hells', 'book', 'mouth', 'electric', 'isnt', 'rables', 'might', 'subject', 'solid', 'society', 'copious', 'peter', 'finalized', 'odd', 'times', 'toward', 'guttenberg', 'bother', 'back', 'viewers', 'kelly', 'casting', 'englishman', 'anything', 'directors', 'jackson', 'amounts', 'books', 'unsuccessfully', 'days', 'worry', 'films', 'crimes', 'print', 'graham', 'ghetto', 'bleak', 'appearance', 'level', 'widower', 'holm', 'psychopath', 'winner', 'better', 'cringed', 'surroundings', 'graphic', 'whether', 'source', 'spawn', 'unfortunate', 'proceeds', 'finished', 'say', 'theory', 'mary', 'even', 'superheroes', 'completely', 'flashy', 'rafael', 'capable', 'strong', 'song', 'east', 'stonecutters', 'steve', 'geared', 'cloaking', 'end', 'make', 'particulars', 'success', 'batman', 'plenty', 'nothing', 'accent', 'starters', 'frederick'}

# %%
def predict_sentiment(review, vocab, tokenizer, model):
	tokens = clean_doc(review)
	# filter by vocab
	tokens = [w for w in tokens if w in vocab]
	# convert to line
	line = ' '.join(tokens)
	# encode
	encoded = tokenizer.texts_to_matrix([line], mode='freq')
	# prediction
	yhat = model.predict(encoded, verbose=0)
	return round(yhat[0,0])

# %%
# test positive text
text = 'Best movie ever!'
print(predict_sentiment(text, vocab, tokenizer, model))
# test negative text
text = 'This is a bad movie.'
print(predict_sentiment(text, vocab, tokenizer, model))
# Out:
# 0.0
# 0.0

# %%
print(type(positive_lines))
print(positive_lines[:5])
print(positive_lines)
# Out:
# <class 'list'>
# ['nothing one first oscar funny peter one job oscar sense oscar could watch named campbell point make course oscar job get go oscar one content well another good end oscar well oscar one oscar great oscar oscar words oscar mouth word oscar isnt one would think would oscar could job oscar see campbell star love oscar campbell never acting campbell film would look film times never well funny original cant dont think identity ending great one better', 'secret even world new look funny find theres place world films dont theres time would might completely well one original time course could see see film funny upon see roles films well dont look films particulars never get like make could wasnt interesting nothing scenes almost get really film well go film back joe say isnt', 'thats film thats seems think end thats actually film find film set flashbacks actually flashbacks get sense would first film well nothing nothing top word nothing case dont see good good', 'good one film plenty plenty good new film thats good acting society like good pales comparison good little set point point success make like', 'film film see films well film well film made question film good bad times good times see dont say dont love film flashbacks film flashbacks see flashbacks get see strong sense really like alan much like another one films one times days go times wasnt first certainly would star certainly past sense world really good films scenes enough make performance performance strong performance one film one funny films acting film make viewers certainly one films say like film one films']
# ['nothing one first oscar funny peter one job oscar sense oscar could watch named campbell point make course oscar job get go oscar one content well another good end oscar well oscar one oscar great oscar oscar words oscar mouth word oscar isnt one would think would oscar could job oscar see campbell star love oscar campbell never acting campbell film would look film times never well funny original cant dont think identity ending great one better', 'secret even world new look funny find theres place world films dont theres time would might completely well one original time course could see see film funny upon see roles films well dont look films particulars never get like make could wasnt interesting nothing scenes almost get really film well go film back joe say isnt', 'thats film thats seems think end thats actually film find film set flashbacks actually flashbacks get sense would first film well nothing nothing top word nothing case dont see good good', 'good one film plenty plenty good new film thats good acting society like good pales comparison good little set point point success make like', 'film film see films well film well film made question film good bad times good times see dont say dont love film flashbacks film flashbacks see flashbacks get see strong sense really like alan much like another one films one times days go times wasnt first certainly would star certainly past sense world really good films scenes enough make performance performance strong performance one film one funny films acting film make viewers certainly one films say like film one films', 'film thats thing dont anyone would film brothers brothers never one another first half brothers get time first half say go watch film good bad see', 'little little little michael isnt new little saying little film see much great film supporting watch little film great even films films kids love one little one film film original theres film little music called get funny little geniuses bad thing geniuses features little theres theres called find films scenes production original first features films production point scenes screenwriters like features film first love one one music song called called features song like time say words hell little song kids kids words cant see kids wont features film good great features could', 'would first saw however even better world one really world world roles world film world see get past love film film one word seems like would never think seems like actually whether good bad one film could thing think star world almost back never star point peter make big performance world world created good point film looks like really think film music film film one films could go one peter see anyone thoroughly film', 'nothing anyone would unfortunate nearly nearly film say attempt world completely film source would novel seems drug world theyre find go includes get back proceeds make first toward toward viewers dont course long police long whether one might one another appearance one films find much film like good like dark getting kids one film first toward really however case one point films course never police first place subject toward created end like much better comparison point better certainly good certainly films would go could make good case films end think might film back films one made one back seems comments seems whether almost think time watch theres', 'question subject first first features viewers set first set isnt see holds little never helped like even though go film unfortunate well almost completely even though really end another film upon however make one film first love scenes well first nearly actually one first half love one another another half go another time go well little film another whole thing much much whole really could nothing films much could words strong isnt film level ending almost upon new film could', 'first big series nothing dont watch say well theres nothing big little find one onto street turns ...

# %%
tokenizer = Tokenizer()
# fit the tokenizer on the documents
docs = positive_lines + negative_lines
tokenizer.fit_on_texts(docs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-6263f7b0f814> in <module>
# ----> 1 tokenizer = Tokenizer()
#       2 # fit the tokenizer on the documents
#       3 docs = positive_lines + negative_lines
#       4 tokenizer.fit_on_texts(docs)
#
# NameError: name 'Tokenizer' is not defined
